# %%
import numpy as np
import os
import pandas as pd
from sqlalchemy import create_engine
import sqlite3

# %%
employee_df = pd.read_csv('employee.csv')
employee_df.set_index('employee_id', drop = True, inplace = True)

employee_df.head(5)
# Out:
#                         employee_name  is_married  marital_status_id  \
# employee_id
# 10026             Adinolfi, Wilson  K           0                  0
# 10084        Ait Sidi, Karthikeyan              1                  1
# 10196               Akinkuolie, Sarah           1                  1
# 10088                    Alagbe,Trina           1                  1
# 10069                Anderson, Carol            0                  2
#
#              gender_id  employee_status_id  department_id  perf_score_id  \
# employee_id
# 10026                1                   1              5              4
# 10084                1                   5              3              3
# 10196                0                   5              5              3
# 10088                0                   1              5              3
# 10069                0                   5              5              3
#
#              is_diversity_job_fair  employee_salary  is_terminated  ...  \
# employee_id                                                         ...
# 10026                            0            62506              0  ...
# 10084                            0           104437              1  ...
# 10196                            0            64955              1  ...
# 10088                            0            64991              0  ...
# 10069                            0            50825              1  ...
#
#                     employee_status         department source_recruiting  \
# employee_id
# 10026                        Active  Production                 LinkedIn
# 10084        Voluntarily Terminated              IT/IS            Indeed
# 10196        Voluntarily Terminated  Production                 LinkedIn
# 10088                        Active  Production                   Indeed
# 10069        Voluntarily Terminated  Production            Google Search
#
#               perf_score survey_engagement_score  \
# employee_id
# 10026            Exceeds                    4.60
# 10084        Fully Meets                    4.96
# 10196        Fully Meets                    3.02
# 10088        Fully Meets                    4.84
# 10069        Fully Meets                    5.00
#
#             survey_emp_satisfaction_score count_special_projects  \
# employee_id
# 10026                                   5                      0
# 10084                                   3                      6
# 10196                                   3                      0
# 10088                                   5                      0
# 10069                                   4                      0
#
#             last_perf_review_date count_days_late_past_30_days count_absences
# employee_id
# 10026                   1/17/2019                            0              1
# 10084                   2/24/2016                            0             17
# 10196                   5/15/2012                            0              3
# 10088                    1/3/2019                            0             15
# 10069                    2/1/2016                            0              2
#
# [5 rows x 33 columns]

# %%
engine = create_engine('sqlite:///hr.sqlite', echo=True)
sqlite_connection = engine.connect()
# Out:
# 2021-08-16 19:03:10,517 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2021-08-16 19:03:10,520 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-16 19:03:10,521 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2021-08-16 19:03:10,522 INFO sqlalchemy.engine.base.Engine ()

# %%
sqlite_table = "employee"
employee_df.to_sql(sqlite_table, sqlite_connection, if_exists='replace')
# Out:
# 2021-08-16 19:03:10,546 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("employee")
# 2021-08-16 19:03:10,547 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-16 19:03:10,549 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("employee")
# 2021-08-16 19:03:10,550 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-16 19:03:10,552 INFO sqlalchemy.engine.base.Engine SELECT name FROM sqlite_master WHERE type='table' ORDER BY name
# 2021-08-16 19:03:10,553 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-16 19:03:10,555 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_xinfo("employee")
# 2021-08-16 19:03:10,556 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-16 19:03:10,559 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2021-08-16 19:03:10,560 INFO sqlalchemy.engine.base.Engine ('employee',)
# 2021-08-16 19:03:10,562 INFO sqlalchemy.engine.base.Engine PRAGMA main.foreign_key_list("employee")
# 2021-08-16 19:03:10,563 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-16 19:03:10,564 INFO sqlalchemy.engine.base.Engine PRAGMA temp.foreign_key_list("employee")
# 2021-08-16 19:03:10,565 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-16 19:03:10,566 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2021-08-16 19:03:10,567 INFO sqlalchemy.engine.base.Engine ('employee',)
# 2021-08-16 19:03:10,569 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_list("employee")
# 2021-08-16 19:03:10,569 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-16 19:03:10,572 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_info("ix_employee_employee_id")
# 2021-08-16 19:03:10,573 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-16 19:03:10,575 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_list("employee")
# 2021-08-16 19:03:10,576 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-16 19:03:10,577 INFO sqlalchemy.engine.base.Engine PRAGMA main.index_info("ix_employee_employee_id")
# 2021-08-16 19:03:10,578 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-16 19:03:10,580 INFO sqlalchemy.engine.base.Engine SELECT sql FROM  (SELECT * FROM sqlite_master UNION ALL   SELECT * FROM sqlite_temp_master) WHERE name = ? AND type = 'table'
# 2021-08-16 19:03:10,580 INFO sqlalchemy.engine.base.Engine ('employee',)
# 2021-08-16 19:03:10,583 INFO sqlalchemy.engine.base.Engine
# DROP TABLE employee
# 2021-08-16 19:03:10,584 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-16 19:03:10,596 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-08-16 19:03:10,601 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE employee (
# 	employee_id BIGINT,
# 	employee_name TEXT,
# 	is_married BIGINT,
# 	marital_status_id BIGINT,
# 	gender_id BIGINT,
# 	employee_status_id BIGINT,
# 	department_id BIGINT,
# 	perf_score_id BIGINT,
# 	is_diversity_job_fair BIGINT,
# 	employee_salary BIGINT,
# 	is_terminated BIGINT,
# 	position_id BIGINT,
# 	position TEXT,
# 	location_state TEXT,
# 	location_zip BIGINT,
# 	employee_dob TEXT,
# 	gender_code TEXT,
# 	marital_status_name TEXT,
# 	citizenship_status TEXT,
# 	is_hispanic_latino TEXT,
# 	employee_race_ethnicity TEXT,
# 	hired_date TEXT,
# 	terminated_date TEXT,
# 	terminated_reason TEXT,
# 	employee_status TEXT,
# 	department TEXT,
# 	source_recruiting TEXT,
# 	perf_score TEXT,
# 	survey_engagement_score FLOAT,
# 	survey_emp_satisfaction_score BIGINT,
# 	count_special_projects BIGINT,
# 	last_perf_review_date TEXT,
# 	count_days_late_past_30_days BIGINT,
# 	count_absences BIGINT
# )
#
#
# 2021-08-16 19:03:10,602 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-16 19:03:10,612 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-08-16 19:03:10,614 INFO sqlalchemy.engine.base.Engine CREATE INDEX ix_employee_employee_id ON employee (employee_id)
# 2021-08-16 19:03:10,615 INFO sqlalchemy.engine.base.Engine ()
# 2021-08-16 19:03:10,623 INFO sqlalchemy.engine.base.Engine COMMIT
# 2021-08-16 19:03:10,627 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2021-08-16 19:03:10,636 INFO sqlalchemy.engine.base.Engine INSERT INTO employee (employee_id, employee_name, is_married, marital_status_id, gender_id, employee_status_id, department_id, perf_score_id, is_diversity_job_fair, employee_salary, is_terminated, position_id, position, location_state, location_zip, employee_dob, gender_code, marital_status_name, citizenship_status, is_hispanic_latino, employee_race_ethnicity, hired_date, terminated_date, terminated_reason, employee_status, department, source_recruiting, perf_score, survey_engagement_score, survey_emp_satisfaction_score, count_special_projects, last_perf_review_date, count_days_late_past_30_days, count_absences) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2021-08-16 19:03:10,637 INFO sqlalchemy.engine.base.Engine ((10026, 'Adinolfi, Wilson  K', 0, 0, 1, 1, 5, 4, 0, 62506, 0, 19, 'Production Technician I', 'MA', 1960, '7/10/1983', 'M ', 'Single', 'US Citizen', 'No', 'White', '7/5/2011', None, None, 'Active', 'Production       ', 'LinkedIn', 'Exceeds', 4.6, 5, 0, '1/17/2019', 0, 1), (10084, 'Ait Sidi, Karthikeyan   ', 1, 1, 1, 5, 3, 3, 0, 104437, 1, 27, 'Sr. DBA', 'MA', 2148, '5/5/1975', 'M ', 'Married', 'US Citizen', 'No', 'White', '3/30/2015', '6/16/2016', 'career change', 'Voluntarily Terminated', 'IT/IS', 'Indeed', 'Fully Meets', 4.96, 3, 6, '2/24/2016', 0, 17), (10196, 'Akinkuolie, Sarah', 1, 1, 0, 5, 5, 3, 0, 64955, 1, 20, 'Production Technician II', 'MA', 1810, '9/19/1988', 'F', 'Married', 'US Citizen', 'No', 'White', '7/5/2011', '9/24/2012', 'hours', 'Voluntarily Terminated', 'Production       ', 'LinkedIn', 'Fully Meets', 3.02, 3, 0, '5/15/2012', 0, 3), (10088, 'Alagbe,Trina', 1, 1, 0, 1, 5, 3, 0, 64991, 0, 19, 'Production Technician I', 'MA', 1886, '9/27/1988', 'F', 'Married', 'US Citizen', 'No', 'White', '1/7/2008', None, None, 'Active', 'Production       ', 'Indeed', 'Fully Meets', 4.84, 5, 0, '1/3/2019', 0, 15), (10069, 'Anderson, Carol ', 0, 2, 0, 5, 5, 3, 0, 50825, 1, 19, 'Production Technician I', 'MA', 2169, '9/8/1989', 'F', 'Divorced', 'US Citizen', 'No', 'White', '7/11/2011', '9/6/2016', 'return to school', 'Voluntarily Terminated', 'Production       ', 'Google Search', 'Fully Meets', 5.0, 4, 0, '2/1/2016', 0, 2), (10002, 'Anderson, Linda  ', 0, 0, 0, 1, 5, 4, 0, 57568, 0, 19, 'Production Technician I', 'MA', 1844, '5/22/1977', 'F', 'Single', 'US Citizen', 'No', 'White', '1/9/2012', None, None, 'Active', 'Production       ', 'LinkedIn', 'Exceeds', 5.0, 5, 0, '1/7/2019', 0, 15), (10194, 'Andreola, Colby', 0, 0, 0, 1, 4, 3, 0, 95660, 0, 24, 'Software Engineer', 'MA', 2110, '5/24/1979', 'F', 'Single', 'US Citizen', 'No', 'White', '11/10/2014', None, None, 'Active', 'Software Engineering', 'LinkedIn', 'Fully Meets', 3.04, 3, 4, '1/2/2019', 0, 19), (10062, 'Athwal, Sam', 0, 4, 1, 1, 5, 3, 0, 59365, 0, 19, 'Production Technician I', 'MA', 2199, '2/18/1983', 'M ', 'Widowed', 'US Citizen', 'No', 'White', '9/30/2013', None, None, 'Active', 'Production       ', 'Employee Referral', 'Fully Meets', 5.0, 4, 0, '2/25/2019', 0, 19)  ... displaying 10 of 311 total bound parameter sets ...  (10043, 'Zhou, Julia', 0, 0, 0, 1, 3, 3, 0, 89292, 0, 9, 'Data Analyst', 'MA', 2148, '2/24/1979', 'F', 'Single', 'US Citizen', 'No', 'White', '3/30/2015', None, None, 'Active', 'IT/IS', 'Employee Referral', 'Fully Meets', 5.0, 3, 5, '2/1/2019', 0, 11), (10271, 'Zima, Colleen', 0, 4, 0, 1, 5, 3, 0, 45046, 0, 19, 'Production Technician I', 'MA', 1730, '8/17/1978', 'F', 'Widowed', 'US Citizen', 'No', 'Asian', '9/29/2014', None, None, 'Active', 'Production       ', 'LinkedIn', 'Fully Meets', 4.5, 5, 0, '1/30/2019', 0, 2))
# 2021-08-16 19:03:10,642 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
sqlite_connection.close()

# %%
# Create a SQL connection to our SQLite database
con = sqlite3.connect("hr.sqlite")

cur = con.cursor()

# The result of a "cursor.execute" can be iterated over by row
for row in cur.execute('SELECT * FROM employee;'):
    print(row)
# Out:
# (10026, 'Adinolfi, Wilson  K', 0, 0, 1, 1, 5, 4, 0, 62506, 0, 19, 'Production Technician I', 'MA', 1960, '7/10/1983', 'M ', 'Single', 'US Citizen', 'No', 'White', '7/5/2011', None, None, 'Active', 'Production       ', 'LinkedIn', 'Exceeds', 4.6, 5, 0, '1/17/2019', 0, 1)
# (10084, 'Ait Sidi, Karthikeyan   ', 1, 1, 1, 5, 3, 3, 0, 104437, 1, 27, 'Sr. DBA', 'MA', 2148, '5/5/1975', 'M ', 'Married', 'US Citizen', 'No', 'White', '3/30/2015', '6/16/2016', 'career change', 'Voluntarily Terminated', 'IT/IS', 'Indeed', 'Fully Meets', 4.96, 3, 6, '2/24/2016', 0, 17)
# (10196, 'Akinkuolie, Sarah', 1, 1, 0, 5, 5, 3, 0, 64955, 1, 20, 'Production Technician II', 'MA', 1810, '9/19/1988', 'F', 'Married', 'US Citizen', 'No', 'White', '7/5/2011', '9/24/2012', 'hours', 'Voluntarily Terminated', 'Production       ', 'LinkedIn', 'Fully Meets', 3.02, 3, 0, '5/15/2012', 0, 3)
# (10088, 'Alagbe,Trina', 1, 1, 0, 1, 5, 3, 0, 64991, 0, 19, 'Production Technician I', 'MA', 1886, '9/27/1988', 'F', 'Married', 'US Citizen', 'No', 'White', '1/7/2008', None, None, 'Active', 'Production       ', 'Indeed', 'Fully Meets', 4.84, 5, 0, '1/3/2019', 0, 15)
# (10069, 'Anderson, Carol ', 0, 2, 0, 5, 5, 3, 0, 50825, 1, 19, 'Production Technician I', 'MA', 2169, '9/8/1989', 'F', 'Divorced', 'US Citizen', 'No', 'White', '7/11/2011', '9/6/2016', 'return to school', 'Voluntarily Terminated', 'Production       ', 'Google Search', 'Fully Meets', 5.0, 4, 0, '2/1/2016', 0, 2)
# (10002, 'Anderson, Linda  ', 0, 0, 0, 1, 5, 4, 0, 57568, 0, 19, 'Production Technician I', 'MA', 1844, '5/22/1977', 'F', 'Single', 'US Citizen', 'No', 'White', '1/9/2012', None, None, 'Active', 'Production       ', 'LinkedIn', 'Exceeds', 5.0, 5, 0, '1/7/2019', 0, 15)
# (10194, 'Andreola, Colby', 0, 0, 0, 1, 4, 3, 0, 95660, 0, 24, 'Software Engineer', 'MA', 2110, '5/24/1979', 'F', 'Single', 'US Citizen', 'No', 'White', '11/10/2014', None, None, 'Active', 'Software Engineering', 'LinkedIn', 'Fully Meets', 3.04, 3, 4, '1/2/2019', 0, 19)
# (10062, 'Athwal, Sam', 0, 4, 1, 1, 5, 3, 0, 59365, 0, 19, 'Production Technician I', 'MA', 2199, '2/18/1983', 'M ', 'Widowed', 'US Citizen', 'No', 'White', '9/30/2013', None, None, 'Active', 'Production       ', 'Employee Referral', 'Fully Meets', 5.0, 4, 0, '2/25/2019', 0, 19)
# (10114, 'Bachiochi, Linda', 0, 0, 0, 3, 5, 3, 1, 47837, 0, 19, 'Production Technician I', 'MA', 1902, '2/11/1970', 'F', 'Single', 'US Citizen', 'No', 'Black or African American', '7/6/2009', None, None, 'Active', 'Production       ', 'Diversity Job Fair', 'Fully Meets', 4.46, 3, 0, '1/25/2019', 0, 4)
# (10250, 'Bacong, Alejandro ', 0, 2, 1, 1, 3, 3, 0, 50178, 0, 14, 'IT Support', 'MA', 1886, '1/7/1988', 'M ', 'Divorced', 'US Citizen', 'No', 'White', '1/5/2015', None, None, 'Active', 'IT/IS', 'Indeed', 'Fully Meets', 5.0, 5, 6, '2/18/2019', 0, 16)
# (10252, 'Baczenski, Rachael  ', 1, 1, 0, 5, 5, 3, 1, 54670, 1, 19, 'Production Technician I', 'MA', 1902, '1/12/1974', 'F', 'Married', 'US Citizen', 'Yes', 'Black or African American', '1/10/2011', '1/12/2017', 'Another position', 'Voluntarily Terminated', 'Production       ', 'Diversity Job Fair', 'Fully Meets', 4.2, 4, 0, '1/30/2016', 0, 12)
# (10242, 'Barbara, Thomas', 1, 1, 1, 5, 5, 3, 1, 47211, 1, 19, 'Production Technician I', 'MA', 2062, '2/21/1974', 'M ', 'Married', 'US Citizen', 'Yes', 'Black or African American', '4/2/2012', '9/19/2016', 'unhappy', 'Voluntarily Terminated', 'Production       ', 'Diversity Job Fair', 'Fully Meets', 4.2, 3, 0, '5/6/2016', 0, 15)
# (10012, 'Barbossa, Hector', 0, 2, 1, 1, 3, 4, 1, 92328, 0, 9, 'Data Analyst', 'TX', 78230, '7/4/1988', 'M ', 'Divorced', 'US Citizen', 'No', 'Black or African American', '11/10/2014', None, None, 'Active', 'IT/IS', 'Diversity Job Fair', 'Exceeds', 4.28, 4, 5, '2/25/2019', 0, 9)
# (10265, 'Barone, Francesco  A', 0, 0, 1, 1, 5, 3, 0, 58709, 0, 19, 'Production Technician I', 'MA', 1810, '7/20/1983', 'M ', 'Single', 'US Citizen', 'No', 'Two or more races', '2/20/2012', None, None, 'Active', 'Production       ', 'Google Search', 'Fully Meets', 4.6, 4, 0, '2/14/2019', 0, 7)
# (10066, 'Barton, Nader', 0, 2, 1, 5, 5, 3, 0, 52505, 1, 19, 'Production Technician I', 'MA', 2747, '7/15/1977', 'M ', 'Divorced', 'US Citizen', 'No', 'White', '9/24/2012', '4/6/2017', 'Another position', 'Voluntarily Terminated', 'Production       ', 'On-line Web application', 'Fully Meets', 5.0, 5, 0, '3/2/2017', 0, 1)
# (10061, 'Bates, Norman', 0, 0, 1, 4, 5, 3, 0, 57834, 1, 19, 'Production Technician I', 'MA', 2050, '10/18/1981', 'M ', 'Single', 'US Citizen', 'No', 'White', '2/21/2011', '8/4/2017', 'attendance', 'Terminated for Cause', 'Production       ', 'Google Search', 'Fully Meets', 5.0, 4, 0, '4/5/2017', 0, 20)
# (10023, 'Beak, Kimberly  ', 1, 1, 0, 2, 5, 4, 0, 70131, 0, 20, 'Production Technician II', 'MA', 2145, '4/17/1966', 'F', 'Married', 'US Citizen', 'No', 'White', '7/21/2016', None, None, 'Active', 'Production       ', 'Employee Referral', 'Exceeds', 4.4, 3, 0, '1/14/2019', 0, 16)
# (10055, 'Beatrice, Courtney ', 0, 0, 0, 1, 5, 3, 0, 59026, 0, 19, 'Production Technician I', 'MA', 1915, '10/27/1970', 'F', 'Single', 'Eligible NonCitizen', 'No', 'White', '4/4/2011', None, None, 'Active', 'Production       ', 'Google Search', 'Fully Meets', 5.0, 5, 0, '1/14/2019', 0, 12)
# (10245, 'Becker, Renee', 0, 0, 0, 4, 3, 3, 0, 110000, 1, 8, 'Database Administrator', 'MA', 2026, '4/4/1986', 'F', 'Single', 'US Citizen', 'Yes', 'White', '7/7/2014', '9/12/2015', 'performance', 'Terminated for Cause', 'IT/IS', 'Google Search', 'Fully Meets', 4.5, 4, 5, '1/15/2015', 0, 8)
# (10277, 'Becker, Scott', 0, 0, 1, 3, 5, 3, 0, 53250, 0, 19, 'Production Technician I', 'MA', 2452, '4/6/1979', 'M ', 'Single', 'US Citizen', 'No', 'Asian', '7/8/2013', None, None, 'Active', 'Production       ', 'LinkedIn', 'Fully Meets', 4.2, 4, 0, '1/11/2019', 0, 13)
# (10046, 'Bernstein, Sean', 0, 0, 1, 1, 5, 3, 0, 51044, 0, 19, 'Production Technician I', 'MA', 2072, '12/22/1970', 'M ', 'Single', 'US Citizen', 'Yes', 'White', '4/2/2012', None, None, 'Active', 'Production       ', 'Google Search', 'Fully Meets', 5.0, 3, 0, '1/14/2019', 0, 13)
# (10226, 'Biden, Lowan  M', 0, 2, 0, 1, 5, 3, 0, 64919, 0, 19, 'Production Technician I', 'MA', 2027, '12/27/1958', 'F', 'Divorced', 'US Citizen', 'No', 'Asian', '8/19/2013', None, None, 'Active', 'Production       ', 'Indeed', 'Fully Meets', 4.2, 3, 0, '1/10/2019', 0, 2)
# (10003, 'Billis, Helen', 1, 1, 0, 1, 5, 4, 0, 62910, 0, 19, 'Production Technician I', 'MA', 2031, '9/1/1989', 'F', 'Married', 'US Citizen', 'No', 'White', '7/7/2014', None, None, 'Active', 'Production       ', 'Indeed', 'Exceeds', 5.0, 3, 0, '2/27/2019', 0, 19)
# (10294, 'Blount, Dianna', 0, 0, 0, 1, 5, 2, 0, 66441, 0, 20, 'Production Technician II', 'MA', 2171, '9/21/1990', 'F', 'Single', 'US Citizen', 'No', 'White', '4/4/2011', None, None, 'Active', 'Production       ', 'CareerBuilder', 'Needs Improvement', 2.0, 3, 0, '2/27/2019', 2, 3)
# (10267, 'Bondwell, Betsy', 0, 0, 0, 5, 5, 3, 0, 57815, 1, 20, 'Production Technician II', 'MA', 2210, '1/16/1967', 'F', 'Single', 'US Citizen', 'No', 'White', '1/10/2011', '4/4/2014', 'career change', 'Voluntarily Terminated', 'Production       ', 'Google Search', 'Fully Meets', 4.8, 5, 0, '3/4/2014', 0, 5)
# (10199, 'Booth, Frank', 0, 0, 1, 4, 3, 3, 0, 103613, 1, 30, 'Enterprise Architect', 'CT', 6033, '7/30/1964', 'M ', 'Single', 'US Citizen', 'No', 'Black or African American', '2/17/2014', '2/19/2016', 'Learned that he is a gangster', 'Terminated for Cause', 'IT/IS', 'LinkedIn', 'Fully Meets', 3.5, 5, 7, '1/10/2016', 0, 2)
# (10081, 'Boutwell, Bonalyn', 1, 1, 0, 1, 1, 3, 1, 106367, 0, 26, 'Sr. Accountant', 'MA', 2468, '4/4/1987', 'F', 'Married', 'US Citizen', 'No', 'Black or African American', '2/16/2015', None, None, 'Active', 'Admin Offices', 'Diversity Job Fair', 'Fully Meets', 5.0, 4, 3, '2/18/2019', 0, 4)
# (10175, 'Bozzi, Charles', 0, 0, 1, 5, 5, 3, 0, 74312, 1, 18, 'Production Manager', 'MA', 1901, '3/10/1970', 'M ', 'Single', 'US Citizen', 'No', 'Asian', '9/30/2013', '8/7/2014', 'retiring', 'Voluntarily Terminated', 'Production       ', 'Indeed', 'Fully Meets', 3.39, 3, 0, '2/20/2014', 0, 14)
# (10177, 'Brill, Donna', 1, 1, 0, 5, 5, 3, 0, 53492, 1, 19, 'Production Technician I', 'MA', 1701, '8/24/1990', 'F', 'Married', 'US Citizen', 'No', 'White', '4/2/2012', '6/15/2013', 'Another position', 'Voluntarily Terminated', 'Production       ', 'Google Search', 'Fully Meets', 3.35, 4, 0, '3/4/2013', 0, 6)
# (10238, 'Brown, Mia', 1, 1, 0, 1, 1, 3, 1, 63000, 0, 1, 'Accountant I', 'MA', 1450, '11/24/1987', 'F', 'Married', 'US Citizen', 'No', 'Black or African American', '10/27/2008', None, None, 'Active', 'Admin Offices', 'Diversity Job Fair', 'Fully Meets', 4.5, 2, 6, '1/15/2019', 0, 14)
# (10184, 'Buccheri, Joseph  ', 0, 0, 1, 1, 5, 3, 0, 65288, 0, 20, 'Production Technician II', 'MA', 1013, '7/28/1983', 'M ', 'Single', 'US Citizen', 'No', 'White', '9/29/2014', None, None, 'Active', 'Production       ', 'Google Search', 'Fully Meets', 3.19, 3, 0, '2/1/2019', 0, 9)
# (10203, 'Bugali, Josephine ', 0, 3, 0, 3, 5, 3, 1, 64375, 0, 19, 'Production Technician I', 'MA', 2043, '10/30/1969', 'F', 'Separated', 'US Citizen', 'No', 'Black or African American', '11/11/2013', None, None, 'Active', 'Production       ', 'Diversity Job Fair', 'Fully Meets', 3.5, 5, 0, '1/21/2019', 0, 17)
# (10188, 'Bunbury, Jessica', 1, 1, 0, 5, 6, 3, 0, 74326, 1, 3, 'Area Sales Manager', 'VA', 21851, '6/1/1964', 'F', 'Married', 'Eligible NonCitizen', 'No', 'Black or African American', '8/15/2011', '8/2/2014', 'Another position', 'Voluntarily Terminated', 'Sales', 'Google Search', 'Fully Meets', 3.14, 5, 0, '2/10/2013', 1, 19)
# (10107, 'Burke, Joelle', 0, 0, 0, 1, 5, 3, 0, 63763, 0, 20, 'Production Technician II', 'MA', 2148, '3/2/1980', 'F', 'Single', 'US Citizen', 'No', 'Black or African American', '3/5/2012', None, None, 'Active', 'Production       ', 'Employee Referral', 'Fully Meets', 4.51, 4, 0, '2/21/2019', 0, 3)
# (10181, 'Burkett, Benjamin ', 1, 1, 1, 1, 5, 3, 0, 62162, 0, 20, 'Production Technician II', 'MA', 1890, '8/19/1977', 'M ', 'Married', 'US Citizen', 'No', 'White', '4/4/2011', None, None, 'Active', 'Production       ', 'Indeed', 'Fully Meets', 3.25, 5, 0, '1/14/2019', 0, 15)
# (10150, 'Cady, Max ', 0, 0, 1, 1, 4, 3, 0, 77692, 0, 25, 'Software Engineering Manager', 'MA', 2184, '11/22/1966', 'M ', 'Single', 'US Citizen', 'No', 'White', '8/15/2011', None, None, 'Active', 'Software Engineering', 'Google Search', 'Fully Meets', 3.84, 3, 5, '1/21/2019', 0, 4)
# (10001, 'Candie, Calvin', 0, 0, 1, 1, 5, 4, 0, 72640, 0, 18, 'Production Manager', 'MA', 2169, '8/9/1983', 'M ', 'Single', 'US Citizen', 'No', 'White', '1/28/2016', None, None, 'Active', 'Production       ', 'Indeed', 'Exceeds', 5.0, 3, 0, '2/22/2019', 0, 14)
# (10085, 'Carabbio, Judith', 0, 0, 0, 1, 4, 3, 0, 93396, 0, 24, 'Software Engineer', 'MA', 2132, '4/5/1987', 'F', 'Single', 'US Citizen', 'No', 'White', '11/11/2013', None, None, 'Active', 'Software Engineering', 'Indeed', 'Fully Meets', 4.96, 4, 6, '1/30/2019', 0, 3)
# (10115, 'Carey, Michael  ', 0, 0, 1, 1, 5, 3, 0, 52846, 0, 19, 'Production Technician I', 'MA', 1701, '2/2/1983', 'M ', 'Single', 'US Citizen', 'No', 'Black or African American', '3/31/2014', None, None, 'Active', 'Production       ', 'LinkedIn', 'Fully Meets', 4.43, 3, 0, '2/1/2019', 0, 14)
# (10082, 'Carr, Claudia  N', 0, 0, 0, 2, 3, 3, 0, 100031, 0, 27, 'Sr. DBA', 'MA', 1886, '6/6/1986', 'F', 'Single', 'US Citizen', 'No', 'Black or African American', '6/30/2016', None, None, 'Active', 'IT/IS', 'LinkedIn', 'Fully Meets', 5.0, 5, 6, '2/18/2019', 0, 7)
# (10040, 'Carter, Michelle ', 0, 0, 0, 1, 6, 3, 0, 71860, 0, 3, 'Area Sales Manager', 'VT', 5664, '5/15/1963', 'F', 'Single', 'US Citizen', 'No', 'White', '8/18/2014', None, None, 'Active', 'Sales', 'Indeed', 'Fully Meets', 5.0, 5, 0, '1/21/2019', 0, 7)
# (10067, 'Chace, Beatrice ', 0, 0, 0, 1, 5, 3, 0, 61656, 0, 19, 'Production Technician I', 'MA', 2763, '1/2/1951', 'F', 'Single', 'US Citizen', 'No', 'White', '9/29/2014', None, None, 'Active', 'Production       ', 'Google Search', 'Fully Meets', 5.0, 4, 0, '2/12/2019', 0, 11)
# (10108, 'Champaigne, Brian', 1, 1, 1, 1, 3, 3, 0, 110929, 0, 5, 'BI Director', 'MA', 2045, '2/9/1972', 'M ', 'Married', 'US Citizen', 'No', 'White', '9/6/2016', None, None, 'Active', 'IT/IS', 'Indeed', 'Fully Meets', 4.5, 5, 7, '1/15/2019', 0, 8)
# (10210, 'Chan, Lin', 0, 0, 0, 1, 5, 3, 0, 54237, 0, 19, 'Production Technician I', 'MA', 2170, '2/12/1979', 'F', 'Single', 'US Citizen', 'No', 'White', '5/12/2014', None, None, 'Active', 'Production       ', 'Indeed', 'Fully Meets', 3.3, 4, 0, '2/19/2019', 0, 11)
# (10154, 'Chang, Donovan  E', 0, 0, 1, 1, 5, 3, 0, 60380, 0, 19, 'Production Technician I', 'MA', 1845, '8/24/1983', 'M ', 'Single', 'US Citizen', 'No', 'White', '7/8/2013', None, None, 'Active', 'Production       ', 'LinkedIn', 'Fully Meets', 3.8, 5, 0, '1/14/2019', 0, 4)
# (10200, 'Chigurh, Anton', 0, 0, 1, 1, 6, 3, 0, 66808, 0, 3, 'Area Sales Manager', 'TX', 78207, '6/11/1970', 'M ', 'Single', 'Eligible NonCitizen', 'No', 'Black or African American', '5/14/2012', None, None, 'Active', 'Sales', 'Employee Referral', 'Fully Meets', 3.0, 5, 0, '1/19/2019', 0, 17)
# (10240, 'Chivukula, Enola', 0, 0, 0, 5, 5, 3, 0, 64786, 1, 19, 'Production Technician I', 'MA', 1775, '8/27/1983', 'F', 'Single', 'US Citizen', 'No', 'White', '6/27/2011', '11/15/2015', 'relocation out of area', 'Voluntarily Terminated', 'Production       ', 'Indeed', 'Fully Meets', 4.3, 4, 0, '3/10/2015', 0, 3)
# (10168, 'Cierpiszewski, Caroline  ', 0, 0, 0, 1, 5, 3, 0, 64816, 0, 19, 'Production Technician I', 'MA', 2044, '5/31/1988', 'F', 'Single', 'Non-Citizen', 'No', 'Black or African American', '10/3/2011', None, None, 'Active', 'Production       ', 'Indeed', 'Fully Meets', 3.58, 5, 0, '1/30/2019', 0, 3)
# (10220, 'Clayton, Rick', 0, 0, 1, 1, 3, 3, 0, 68678, 0, 14, 'IT Support', 'MA', 2170, '9/5/1985', 'M ', 'Single', 'US Citizen', 'No', 'White', '9/5/2012', None, None, 'Active', 'IT/IS', 'Indeed', 'Fully Meets', 4.7, 3, 6, '2/27/2019', 0, 2)
# (10275, 'Cloninger, Jennifer', 1, 1, 0, 5, 5, 3, 0, 64066, 1, 20, 'Production Technician II', 'MA', 1752, '8/31/1981', 'F', 'Married', 'US Citizen', 'No', 'White', '5/16/2011', '1/7/2013', 'unhappy', 'Voluntarily Terminated', 'Production       ', 'Google Search', 'Fully Meets', 4.2, 5, 0, '5/3/2012', 0, 9)
# (10269, 'Close, Phil', 1, 1, 1, 5, 5, 3, 0, 59369, 1, 20, 'Production Technician II', 'MA', 2169, '11/25/1978', 'M ', 'Married', 'US Citizen', 'No', 'White', '8/30/2010', '9/26/2011', 'career change', 'Voluntarily Terminated', 'Production       ', 'Indeed', 'Fully Meets', 4.2, 4, 0, '5/4/2011', 0, 6)
# (10029, 'Clukey, Elijian', 1, 1, 1, 2, 5, 4, 0, 50373, 0, 19, 'Production Technician I', 'MA', 2134, '8/26/1980', 'M ', 'Married', 'US Citizen', 'No', 'White', '7/6/2016', None, None, 'Active', 'Production       ', 'Employee Referral', 'Exceeds', 4.1, 4, 0, '2/28/2019', 0, 5)
# (10261, 'Cockel, James', 0, 0, 1, 1, 5, 3, 0, 63108, 0, 19, 'Production Technician I', 'MA', 2452, '9/8/1977', 'M ', 'Single', 'US Citizen', 'No', 'White', '7/8/2013', None, None, 'Active', 'Production       ', 'Employee Referral', 'Fully Meets', 4.4, 5, 0, '1/14/2019', 0, 3)
# (10292, 'Cole, Spencer', 0, 0, 1, 4, 5, 2, 0, 59144, 1, 19, 'Production Technician I', 'MA', 1880, '8/12/1979', 'M ', 'Single', 'US Citizen', 'No', 'Black or African American', '7/11/2011', '9/23/2016', 'performance', 'Terminated for Cause', 'Production       ', 'LinkedIn', 'Needs Improvement', 2.0, 3, 0, '5/1/2016', 5, 16)
# (10282, 'Corleone, Michael', 0, 2, 1, 1, 5, 2, 0, 68051, 0, 18, 'Production Manager', 'MA', 1803, '12/17/1975', 'M ', 'Divorced', 'US Citizen', 'No', 'White', '7/20/2010', None, None, 'Active', 'Production       ', 'CareerBuilder', 'Needs Improvement', 4.13, 2, 0, '1/14/2019', 3, 3)
# (10019, 'Corleone, Vito', 0, 0, 1, 1, 5, 4, 0, 170500, 0, 10, 'Director of Operations', 'MA', 2030, '3/19/1983', 'M ', 'Single', 'US Citizen', 'No', 'Black or African American', '1/5/2009', None, None, 'Active', 'Production       ', 'Indeed', 'Exceeds', 3.7, 5, 0, '2/4/2019', 0, 15)
# (10094, 'Cornett, Lisa ', 1, 1, 0, 1, 5, 3, 0, 63381, 0, 19, 'Production Technician I', 'MA', 2189, '3/31/1977', 'F', 'Married', 'US Citizen', 'Yes', 'White', '1/5/2015', None, None, 'Active', 'Production       ', 'Indeed', 'Fully Meets', 4.73, 5, 0, '2/14/2019', 0, 6)
# (10193, 'Costello, Frank', 1, 1, 1, 1, 3, 3, 0, 83552, 0, 9, 'Data Analyst', 'MA', 1810, '8/26/1986', 'M ', 'Married', 'US Citizen', 'No', 'White', '3/30/2015', None, None, 'Active', 'IT/IS', 'Indeed', 'Fully Meets', 3.04, 3, 6, '1/22/2019', 0, 2)
# (10132, 'Crimmings,   Jean', 0, 0, 0, 2, 5, 3, 0, 56149, 0, 19, 'Production Technician I', 'MA', 1821, '4/10/1987', 'F', 'Single', 'US Citizen', 'No', 'White', '7/6/2016', None, None, 'Active', 'Production       ', 'LinkedIn', 'Fully Meets', 4.12, 5, 0, '1/28/2019', 0, 15)
# (10083, 'Cross, Noah', 0, 0, 1, 1, 3, 3, 0, 92329, 0, 28, 'Sr. Network Engineer', 'CT', 6278, '9/9/1965', 'M ', 'Single', 'US Citizen', 'No', 'White', '11/10/2014', None, None, 'Active', 'IT/IS', 'Employee Referral', 'Fully Meets', 5.0, 3, 4, '1/2/2019', 0, 5)
# (10099, 'Daneault, Lynn', 0, 0, 0, 1, 6, 3, 0, 65729, 0, 21, 'Sales Manager', 'VT', 5473, '4/19/1990', 'F', 'Single', 'US Citizen', 'No', 'White', '5/5/2014', None, None, 'Active', 'Sales', 'Indeed', 'Fully Meets', 4.62, 4, 0, '1/24/2019', 0, 8)
# (10212, 'Daniele, Ann  ', 1, 1, 0, 3, 3, 3, 0, 85028, 0, 28, 'Sr. Network Engineer', 'CT', 6033, '1/18/1952', 'F', 'Married', 'US Citizen', 'No', 'White', '11/10/2014', None, None, 'Active', 'IT/IS', 'LinkedIn', 'Fully Meets', 3.1, 5, 8, '2/12/2019', 0, 19)
# (10056, "Darson, Jene'ya ", 1, 1, 0, 1, 5, 3, 0, 57583, 0, 19, 'Production Technician I', 'MA', 2110, '11/5/1978', 'F', 'Married', 'US Citizen', 'No', 'White', '7/2/2012', None, None, 'Active', 'Production       ', 'Indeed', 'Fully Meets', 5.0, 3, 0, '2/25/2019', 0, 1)
# (10143, 'Davis, Daniel', 0, 0, 1, 1, 5, 3, 0, 56294, 0, 20, 'Production Technician II', 'MA', 2458, '9/14/1979', 'M ', 'Single', 'Eligible NonCitizen', 'No', 'Two or more races', '11/7/2011', None, None, 'Active', 'Production       ', 'LinkedIn', 'Fully Meets', 3.96, 4, 0, '2/27/2019', 0, 6)
# (10311, 'Dee, Randy', 1, 1, 1, 1, 6, 1, 0, 56991, 0, 19, 'Production Technician I', 'MA', 2138, '4/15/1988', 'M ', 'Married', 'US Citizen', 'No', 'White', '7/9/2018', None, None, 'Active', 'Production       ', 'Indeed', 'Fully Meets', 4.3, 4, 3, '1/31/2019', 2, 2)
# (10070, 'DeGweck,  James', 1, 1, 1, 5, 5, 3, 0, 55722, 1, 19, 'Production Technician I', 'MA', 1810, '10/31/1977', 'M ', 'Married', 'US Citizen', 'No', 'White', '5/16/2011', '6/8/2016', 'unhappy', 'Voluntarily Terminated', 'Production       ', 'Indeed', 'Fully Meets', 5.0, 4, 0, '4/2/2016', 0, 14)
# (10155, 'Del Bosque, Keyla', 0, 0, 0, 1, 4, 3, 0, 101199, 0, 24, 'Software Engineer', 'MA', 2176, '7/5/1979', 'F', 'Single', 'US Citizen', 'No', 'Black or African American', '1/9/2012', None, None, 'Active', 'Software Engineering', 'CareerBuilder', 'Fully Meets', 3.79, 5, 5, '1/25/2019', 0, 8)
# (10306, 'Delarge, Alex', 0, 0, 1, 1, 6, 1, 0, 61568, 0, 3, 'Area Sales Manager', 'AL', 36006, '11/2/1975', 'M ', 'Single', 'US Citizen', 'No', 'Two or more races', '9/29/2014', None, None, 'Active', 'Sales', 'Indeed', 'PIP', 1.93, 3, 0, '1/30/2019', 6, 5)
# (10100, 'Demita, Carla', 0, 3, 0, 5, 5, 3, 0, 58275, 1, 20, 'Production Technician II', 'MA', 2343, '2/25/1951', 'F', 'Separated', 'US Citizen', 'No', 'Black or African American', '4/4/2011', '11/4/2015', 'more money', 'Voluntarily Terminated', 'Production       ', 'Google Search', 'Fully Meets', 4.62, 5, 0, '5/6/2015', 0, 1)
# (10310, 'Desimone, Carl ', 1, 1, 1, 1, 5, 1, 0, 53189, 0, 19, 'Production Technician I', 'MA', 2061, '4/19/1967', 'M ', 'Married', 'US Citizen', 'No', 'White', '7/7/2014', None, None, 'Active', 'Production       ', 'Indeed', 'PIP', 1.12, 2, 0, '1/31/2019', 4, 9)
# (10197, 'DeVito, Tommy', 0, 0, 1, 1, 3, 3, 0, 96820, 0, 4, 'BI Developer', 'MA', 2045, '9/4/1983', 'M ', 'Single', 'US Citizen', 'No', 'White', '2/15/2017', None, None, 'Active', 'IT/IS', 'Indeed', 'Fully Meets', 3.01, 5, 7, '1/23/2019', 0, 15)
# (10276, 'Dickinson, Geoff ', 0, 0, 1, 1, 5, 3, 0, 51259, 0, 19, 'Production Technician I', 'MA', 2180, '11/15/1982', 'M ', 'Single', 'US Citizen', 'No', 'White', '5/12/2014', None, None, 'Active', 'Production       ', 'Indeed', 'Fully Meets', 4.3, 4, 0, '2/19/2019', 0, 1)
# (10304, 'Dietrich, Jenna  ', 0, 0, 0, 1, 6, 1, 0, 59231, 0, 3, 'Area Sales Manager', 'WA', 98052, '5/14/1987', 'F', 'Single', 'US Citizen', 'Yes', 'White', '2/20/2012', None, None, 'Active', 'Sales', 'Website', 'PIP', 2.3, 1, 0, '1/29/2019', 2, 17)
# (10284, 'DiNocco, Lily ', 1, 1, 0, 1, 5, 2, 0, 61584, 0, 19, 'Production Technician I', 'MA', 2351, '12/2/1978', 'F', 'Married', 'US Citizen', 'No', 'Black or African American', '1/7/2013', None, None, 'Active', 'Production       ', 'Indeed', 'Needs Improvement', 3.88, 4, 0, '1/18/2019', 0, 6)
# (10207, 'Dobrin, Denisa  S', 0, 0, 0, 1, 5, 3, 0, 46335, 0, 19, 'Production Technician I', 'MA', 2125, '10/7/1986', 'F', 'Single', 'US Citizen', 'Yes', 'White', '4/2/2012', None, None, 'Active', 'Production       ', 'CareerBuilder', 'Fully Meets', 3.4, 5, 0, '2/19/2019', 0, 15)
# (10133, 'Dolan, Linda', 1, 1, 0, 1, 3, 3, 0, 70621, 0, 14, 'IT Support', 'MA', 2119, '7/18/1988', 'F', 'Married', 'US Citizen', 'No', 'White', '1/5/2015', None, None, 'Active', 'IT/IS', 'Employee Referral', 'Fully Meets', 4.11, 4, 6, '2/25/2019', 0, 16)
# (10028, 'Dougall, Eric', 0, 0, 1, 1, 3, 4, 0, 138888, 0, 13, 'IT Manager - Support', 'MA', 1886, '7/9/1970', 'M ', 'Single', 'US Citizen', 'No', 'Black or African American', '1/5/2014', None, None, 'Active', 'IT/IS', 'Indeed', 'Exceeds', 4.3, 5, 5, '1/4/2019', 0, 4)
# (10006, 'Driver, Elle', 0, 0, 0, 1, 6, 4, 0, 74241, 0, 3, 'Area Sales Manager', 'CA', 90007, '11/8/1988', 'F', 'Single', 'US Citizen', 'No', 'White', '1/10/2011', None, None, 'Active', 'Sales', 'Indeed', 'Exceeds', 4.77, 5, 0, '1/27/2019', 0, 14)
# (10105, 'Dunn, Amy  ', 0, 0, 0, 1, 5, 3, 0, 75188, 0, 18, 'Production Manager', 'MA', 1731, '11/28/1973', 'F', 'Single', 'US Citizen', 'No', 'White', '9/18/2014', None, None, 'Active', 'Production       ', 'Google Search', 'Fully Meets', 4.52, 4, 0, '1/15/2019', 0, 4)
# (10211, 'Dunne, Amy', 1, 1, 0, 1, 5, 3, 0, 62514, 0, 19, 'Production Technician I', 'MA', 1749, '9/23/1973', 'F', 'Married', 'US Citizen', 'No', 'White', '4/26/2010', None, None, 'Active', 'Production       ', 'Google Search', 'Fully Meets', 2.9, 3, 0, '1/21/2019', 0, 6)
# (10064, 'Eaton, Marianne', 1, 1, 0, 5, 5, 3, 0, 60070, 1, 19, 'Production Technician I', 'MA', 2343, '9/5/1991', 'F', 'Married', 'US Citizen', 'No', 'White', '4/4/2011', '6/6/2017', 'military', 'Voluntarily Terminated', 'Production       ', 'Google Search', 'Fully Meets', 5.0, 3, 0, '4/9/2017', 0, 7)
# (10247, 'Engdahl, Jean', 0, 0, 1, 1, 5, 3, 0, 48888, 0, 19, 'Production Technician I', 'MA', 2026, '5/31/1974', 'M ', 'Single', 'US Citizen', 'No', 'White', '11/10/2014', None, None, 'Active', 'Production       ', 'LinkedIn', 'Fully Meets', 4.7, 5, 0, '2/13/2019', 0, 8)
# (10235, 'England, Rex', 1, 1, 1, 1, 5, 3, 0, 54285, 0, 19, 'Production Technician I', 'MA', 2045, '8/25/1978', 'M ', 'Married', 'US Citizen', 'No', 'White', '3/31/2014', None, None, 'Active', 'Production       ', 'Employee Referral', 'Fully Meets', 4.2, 3, 0, '1/11/2019', 0, 3)
# (10299, 'Erilus, Angela', 0, 3, 0, 1, 5, 1, 0, 56847, 0, 20, 'Production Technician II', 'MA', 2133, '8/25/1989', 'F', 'Separated', 'US Citizen', 'No', 'White', '7/7/2014', None, None, 'Active', 'Production       ', 'Indeed', 'PIP', 3.0, 1, 0, '2/25/2019', 2, 5)
# (10280, 'Estremera, Miguel', 0, 0, 1, 4, 5, 2, 0, 60340, 1, 19, 'Production Technician I', 'MA', 2129, '9/2/1983', 'M ', 'Single', 'US Citizen', 'No', 'White', '4/2/2012', '9/27/2018', 'attendance', 'Terminated for Cause', 'Production       ', 'Google Search', 'Needs Improvement', 5.0, 4, 0, '4/12/2018', 5, 16)
# (10296, 'Evensen, April', 0, 0, 0, 4, 5, 2, 0, 59124, 1, 19, 'Production Technician I', 'MA', 2458, '5/6/1989', 'F', 'Single', 'US Citizen', 'No', 'White', '2/17/2014', '2/25/2018', 'no-call, no-show', 'Terminated for Cause', 'Production       ', 'Google Search', 'Needs Improvement', 2.3, 3, 0, '1/15/2017', 5, 19)
# (10290, 'Exantus, Susan', 1, 1, 0, 4, 4, 2, 0, 99280, 1, 24, 'Software Engineer', 'MA', 1749, '5/15/1987', 'F', 'Married', 'US Citizen', 'No', 'Black or African American', '5/2/2011', '6/5/2013', 'attendance', 'Terminated for Cause', 'Software Engineering', 'Indeed', 'Needs Improvement', 2.1, 5, 4, '8/10/2012', 4, 19)
# (10263, 'Faller, Megan ', 1, 1, 0, 1, 5, 3, 0, 71776, 0, 20, 'Production Technician II', 'MA', 1824, '9/22/1978', 'F', 'Married', 'US Citizen', 'No', 'Black or African American', '7/7/2014', None, None, 'Active', 'Production       ', 'LinkedIn', 'Fully Meets', 4.4, 5, 0, '2/22/2019', 0, 17)
# (10136, 'Fancett, Nicole', 0, 0, 0, 1, 5, 3, 0, 65902, 0, 20, 'Production Technician II', 'MA', 2324, '9/27/1987', 'F', 'Single', 'US Citizen', 'No', 'Black or African American', '2/17/2014', None, None, 'Active', 'Production       ', 'LinkedIn', 'Fully Meets', 4.0, 4, 0, '1/7/2019', 0, 7)
# (10189, 'Ferguson, Susan', 1, 1, 0, 5, 5, 3, 0, 57748, 1, 19, 'Production Technician I', 'MA', 2176, '4/14/1955', 'F', 'Married', 'US Citizen', 'No', 'White', '11/7/2011', '5/17/2016', 'military', 'Voluntarily Terminated', 'Production       ', 'Google Search', 'Fully Meets', 3.13, 3, 0, '2/4/2016', 0, 16)
# (10308, 'Fernandes, Nilson  ', 1, 1, 1, 1, 5, 1, 0, 64057, 0, 19, 'Production Technician I', 'MA', 2132, '10/18/1989', 'M ', 'Married', 'US Citizen', 'No', 'White', '5/11/2015', None, None, 'Active', 'Production       ', 'Indeed', 'PIP', 1.56, 5, 0, '1/3/2019', 6, 15)
# (10309, 'Fett, Boba', 0, 0, 1, 1, 3, 1, 0, 53366, 0, 15, 'Network Engineer', 'MA', 2138, '6/18/1987', 'M ', 'Single', 'US Citizen', 'No', 'White', '3/30/2015', None, None, 'Active', 'IT/IS', 'LinkedIn', 'PIP', 1.2, 3, 6, '2/4/2019', 3, 2)
# (10049, 'Fidelia,  Libby', 1, 1, 0, 1, 5, 3, 0, 58530, 0, 19, 'Production Technician I', 'MA', 2155, '3/16/1981', 'F', 'Married', 'US Citizen', 'No', 'White', '1/9/2012', None, None, 'Active', 'Production       ', 'Google Search', 'Fully Meets', 5.0, 5, 0, '1/29/2019', 0, 19)
# (10093, 'Fitzpatrick, Michael  J', 0, 0, 1, 5, 5, 3, 0, 72609, 1, 20, 'Production Technician II', 'MA', 2143, '10/1/1981', 'M ', 'Single', 'US Citizen', 'Yes', 'White', '5/16/2011', '6/24/2013', 'hours', 'Voluntarily Terminated', 'Production       ', 'Google Search', 'Fully Meets', 4.76, 5, 0, '4/5/2013', 0, 20)
# (10163, 'Foreman, Tanya', 1, 1, 0, 5, 5, 3, 0, 55965, 1, 20, 'Production Technician II', 'MA', 2170, '11/8/1983', 'F', 'Married', 'US Citizen', 'No', 'White', '4/4/2011', '1/9/2013', 'career change', 'Voluntarily Terminated', 'Production       ', 'Google Search', 'Fully Meets', 3.66, 3, 0, '1/7/2012', 0, 6)
# (10305, 'Forrest, Alex', 1, 1, 1, 1, 6, 3, 0, 70187, 1, 3, 'Area Sales Manager', 'MA', 2330, '7/7/1975', 'M ', 'Married', 'US Citizen', 'No', 'White', '9/29/2014', '8/19/2018', 'Fatal attraction', 'Terminated for Cause', 'Sales', 'Employee Referral', 'PIP', 2.0, 5, 0, '1/28/2019', 4, 7)
# (10015, 'Foss, Jason', 0, 0, 1, 1, 3, 4, 0, 178000, 0, 12, 'IT Director', 'MA', 1460, '7/5/1980', 'M ', 'Single', 'US Citizen', 'No', 'Black or African American', '4/15/2011', None, None, 'Active', 'IT/IS', 'Indeed', 'Exceeds', 5.0, 5, 5, '1/7/2019', 0, 15)
# (10080, 'Foster-Baker, Amy', 1, 1, 0, 1, 1, 3, 0, 99351, 0, 26, 'Sr. Accountant', 'MA', 2050, '4/16/1979', 'F', 'Married', 'US Citizen', 'no', 'White', '1/5/2009', None, None, 'Active', 'Admin Offices', 'Other', 'Fully Meets', 5.0, 3, 2, '2/8/2019', 0, 3)
# (10258, 'Fraval, Maruk ', 0, 0, 1, 1, 6, 3, 0, 67251, 0, 3, 'Area Sales Manager', 'CT', 6050, '8/28/1963', 'M ', 'Single', 'US Citizen', 'No', 'Black or African American', '9/6/2011', None, None, 'Active', 'Sales', 'CareerBuilder', 'Fully Meets', 4.3, 3, 0, '1/27/2019', 2, 7)
# (10273, 'Galia, Lisa', 0, 0, 0, 1, 3, 3, 0, 65707, 0, 14, 'IT Support', 'CT', 6040, '7/6/1968', 'F', 'Single', 'US Citizen', 'No', 'White', '5/1/2010', None, None, 'Active', 'IT/IS', 'LinkedIn', 'Fully Meets', 4.7, 4, 5, '2/1/2019', 0, 1)
# (10111, 'Garcia, Raul', 0, 0, 1, 1, 5, 3, 0, 52249, 0, 19, 'Production Technician I', 'MA', 1905, '9/15/1985', 'M ', 'Single', 'US Citizen', 'Yes', 'White', '3/30/2015', None, None, 'Active', 'Production       ', 'Employee Referral', 'Fully Meets', 4.5, 3, 0, '2/18/2019', 0, 5)
# (10257, 'Gaul, Barbara', 0, 0, 0, 1, 5, 3, 0, 53171, 0, 19, 'Production Technician I', 'MA', 2121, '12/2/1983', 'F', 'Single', 'US Citizen', 'Yes', 'Black or African American', '5/16/2011', None, None, 'Active', 'Production       ', 'LinkedIn', 'Fully Meets', 4.2, 4, 0, '2/26/2019', 0, 12)
# (10159, 'Gentry, Mildred', 1, 1, 0, 1, 5, 3, 0, 51337, 0, 19, 'Production Technician I', 'MA', 2145, '10/1/1990', 'F', 'Married', 'US Citizen', 'No', 'Black or African American', '3/30/2015', None, None, 'Active', 'Production       ', 'LinkedIn', 'Fully Meets', 3.73, 3, 0, '1/16/2019', 0, 19)
# (10122, 'Gerke, Melisa', 0, 2, 0, 5, 5, 3, 1, 51505, 1, 19, 'Production Technician I', 'MA', 2330, '5/15/1970', 'F', 'Divorced', 'US Citizen', 'No', 'Black or African American', '11/7/2011', '11/15/2016', 'hours', 'Voluntarily Terminated', 'Production       ', 'Diversity Job Fair', 'Fully Meets', 4.24, 4, 0, '4/29/2016', 0, 2)
# (10142, 'Gill, Whitney  ', 0, 4, 0, 4, 6, 3, 0, 59370, 1, 3, 'Area Sales Manager', 'OH', 43050, '7/10/1971', 'F', 'Widowed', 'US Citizen', 'No', 'Black or African American', '7/7/2014', '9/5/2015', 'attendance', 'Terminated for Cause', 'Sales', 'CareerBuilder', 'Fully Meets', 3.97, 4, 0, '1/15/2014', 0, 7)
# (10283, 'Gilles, Alex', 1, 1, 1, 5, 5, 2, 1, 54933, 1, 19, 'Production Technician I', 'MA', 2062, '8/9/1974', 'M ', 'Married', 'US Citizen', 'No', 'Black or African American', '4/2/2012', '6/25/2015', 'military', 'Voluntarily Terminated', 'Production       ', 'Diversity Job Fair', 'Needs Improvement', 3.97, 4, 0, '1/20/2015', 3, 15)
# (10018, 'Girifalco, Evelyn', 0, 0, 0, 1, 5, 4, 0, 57815, 0, 19, 'Production Technician I', 'MA', 2451, '5/8/1980', 'F', 'Single', 'US Citizen', 'Yes', 'Two or more races', '9/29/2014', None, None, 'Active', 'Production       ', 'Indeed', 'Exceeds', 3.9, 4, 0, '2/7/2019', 0, 3)
# (10255, 'Givens, Myriam', 0, 0, 0, 1, 6, 3, 0, 61555, 0, 3, 'Area Sales Manager', 'IN', 46204, '9/22/1989', 'F', 'Single', 'US Citizen', 'No', 'White', '2/16/2015', None, None, 'Active', 'Sales', 'Indeed', 'Fully Meets', 4.5, 5, 0, '1/25/2019', 0, 20)
# (10246, 'Goble, Taisha', 0, 0, 0, 4, 3, 3, 0, 114800, 1, 8, 'Database Administrator', 'MA', 2127, '10/23/1971', 'F', 'Single', 'US Citizen', 'No', 'White', '2/16/2015', '3/15/2015', 'no-call, no-show', 'Terminated for Cause', 'IT/IS', 'Indeed', 'Fully Meets', 4.6, 4, 4, '1/20/2015', 0, 10)
# (10228, 'Goeth, Amon', 1, 1, 1, 1, 3, 3, 0, 74679, 0, 14, 'IT Support', 'MA', 2135, '11/24/1989', 'M ', 'Married', 'US Citizen', 'Yes', 'White', '3/30/2015', None, None, 'Active', 'IT/IS', 'LinkedIn', 'Fully Meets', 4.3, 5, 7, '1/10/2019', 0, 20)
# (10243, 'Gold, Shenice  ', 0, 0, 0, 1, 5, 3, 0, 53018, 0, 19, 'Production Technician I', 'MA', 2451, '6/18/1992', 'F', 'Single', 'US Citizen', 'Yes', 'White', '11/11/2013', None, None, 'Active', 'Production       ', 'Indeed', 'Fully Meets', 4.3, 5, 0, '2/18/2019', 0, 7)
# (10031, 'Gonzalez, Cayo', 0, 2, 1, 1, 5, 4, 1, 59892, 0, 19, 'Production Technician I', 'MA', 2108, '9/29/1969', 'M ', 'Divorced', 'US Citizen', 'No', 'Black or African American', '7/11/2011', None, None, 'Active', 'Production       ', 'Diversity Job Fair', 'Exceeds', 4.5, 4, 0, '2/18/2019', 0, 1)
# (10300, 'Gonzalez, Juan', 1, 1, 1, 5, 5, 1, 1, 68898, 1, 20, 'Production Technician II', 'MA', 2128, '10/12/1964', 'M ', 'Married', 'US Citizen', 'No', 'Black or African American', '4/26/2010', '5/30/2011', 'career change', 'Voluntarily Terminated', 'Production       ', 'Diversity Job Fair', 'PIP', 3.0, 3, 0, '3/6/2011', 3, 10)
# (10101, 'Gonzalez, Maria', 0, 3, 0, 1, 3, 3, 0, 61242, 0, 14, 'IT Support', 'MA', 2472, '4/16/1981', 'F', 'Separated', 'US Citizen', 'Yes', 'White', '1/5/2015', None, None, 'Active', 'IT/IS', 'Employee Referral', 'Fully Meets', 4.61, 4, 5, '1/28/2019', 0, 11)
# (10237, 'Good, Susan', 1, 1, 0, 3, 5, 3, 0, 66825, 0, 20, 'Production Technician II', 'MA', 1886, '5/25/1986', 'F', 'Married', 'US Citizen', 'No', 'White', '5/12/2014', None, None, 'Active', 'Production       ', 'LinkedIn', 'Fully Meets', 4.6, 3, 0, '2/7/2019', 0, 20)
# (10051, 'Gordon, David', 1, 1, 1, 1, 5, 3, 0, 48285, 0, 19, 'Production Technician I', 'MA', 2169, '5/21/1979', 'M ', 'Married', 'US Citizen', 'No', 'White', '7/2/2012', None, None, 'Active', 'Production       ', 'LinkedIn', 'Fully Meets', 5.0, 3, 0, '1/14/2019', 0, 2)
# (10218, 'Gosciminski, Phylicia  ', 0, 3, 0, 3, 5, 3, 0, 66149, 0, 20, 'Production Technician II', 'MA', 1824, '12/8/1983', 'F', 'Separated', 'US Citizen', 'No', 'American Indian or Alaska Native', '9/30/2013', None, None, 'Active', 'Production       ', 'Google Search', 'Fully Meets', 4.4, 5, 0, '2/21/2019', 0, 1)
# (10256, 'Goyal, Roxana', 1, 1, 0, 3, 5, 3, 0, 49256, 0, 19, 'Production Technician I', 'MA', 1864, '10/9/1974', 'F', 'Married', 'US Citizen', 'No', 'Asian', '8/19/2013', None, None, 'Active', 'Production       ', 'LinkedIn', 'Fully Meets', 4.1, 5, 0, '2/15/2019', 0, 3)
# (10098, 'Gray, Elijiah  ', 0, 2, 1, 1, 5, 3, 0, 62957, 0, 18, 'Production Manager', 'MA', 1752, '7/11/1981', 'M ', 'Divorced', 'US Citizen', 'No', 'White', '6/2/2015', None, None, 'Active', 'Production       ', 'Employee Referral', 'Fully Meets', 4.63, 3, 0, '1/4/2019', 0, 2)
# (10059, 'Gross, Paula', 0, 2, 0, 5, 5, 3, 0, 63813, 1, 19, 'Production Technician I', 'MA', 2176, '5/21/1983', 'F', 'Divorced', 'US Citizen', 'No', 'White', '2/21/2011', '1/11/2014', 'more money', 'Voluntarily Terminated', 'Production       ', 'CareerBuilder', 'Fully Meets', 5.0, 5, 0, '6/3/2013', 0, 17)
# (10234, 'Gruber, Hans', 1, 1, 1, 1, 3, 3, 0, 99020, 0, 4, 'BI Developer', 'MA', 2134, '6/30/1989', 'M ', 'Married', 'US Citizen', 'No', 'Black or African American', '4/20/2017', None, None, 'Active', 'IT/IS', 'Indeed', 'Fully Meets', 4.2, 5, 5, '1/28/2019', 0, 8)
# (10109, 'Guilianno, Mike', 0, 0, 1, 5, 6, 3, 0, 71707, 1, 3, 'Area Sales Manager', 'TN', 37129, '2/9/1969', 'M ', 'Single', 'US Citizen', 'No', 'Two or more races', '3/7/2012', '10/31/2014', 'relocation out of area', 'Voluntarily Terminated', 'Sales', 'LinkedIn', 'Fully Meets', 4.5, 5, 0, '2/1/2013', 0, 20)
# (10125, 'Handschiegl, Joanne', 1, 1, 0, 1, 5, 3, 0, 54828, 0, 19, 'Production Technician I', 'MA', 2127, '3/23/1977', 'F', 'Married', 'US Citizen', 'No', 'White', '11/28/2011', None, None, 'Active', 'Production       ', 'Google Search', 'Fully Meets', 4.2, 4, 0, '2/22/2019', 0, 13)
# (10074, 'Hankard, Earnest', 0, 0, 1, 1, 5, 3, 0, 64246, 0, 20, 'Production Technician II', 'MA', 2155, '8/10/1988', 'M ', 'Single', 'US Citizen', 'Yes', 'White', '11/11/2013', None, None, 'Active', 'Production       ', 'LinkedIn', 'Fully Meets', 5.0, 3, 0, '1/8/2019', 0, 20)
# (10097, 'Harrington, Christie ', 0, 0, 0, 5, 5, 3, 0, 52177, 1, 19, 'Production Technician I', 'MA', 2324, '8/18/1952', 'F', 'Single', 'US Citizen', 'No', 'White', '1/9/2012', '12/15/2015', 'retiring', 'Voluntarily Terminated', 'Production       ', 'CareerBuilder', 'Fully Meets', 4.64, 4, 0, '5/2/2015', 0, 8)
# (10007, 'Harrison, Kara', 1, 1, 0, 1, 5, 4, 0, 62065, 0, 19, 'Production Technician I', 'MA', 1886, '5/2/1974', 'F', 'Married', 'US Citizen', 'No', 'White', '5/12/2014', None, None, 'Active', 'Production       ', 'CareerBuilder', 'Exceeds', 4.76, 4, 0, '2/15/2019', 0, 5)
# (10129, 'Heitzman, Anthony', 0, 0, 1, 1, 5, 3, 0, 46998, 0, 19, 'Production Technician I', 'MA', 2149, '1/4/1984', 'M ', 'Single', 'US Citizen', 'No', 'White', '8/13/2012', None, None, 'Active', 'Production       ', 'Google Search', 'Fully Meets', 4.17, 4, 0, '2/11/2019', 0, 1)
# (10075, 'Hendrickson, Trina', 0, 0, 0, 5, 5, 3, 0, 68099, 1, 20, 'Production Technician II', 'MA', 2021, '8/27/1972', 'F', 'Single', 'US Citizen', 'No', 'White', '1/10/2011', '6/18/2013', 'hours', 'Voluntarily Terminated', 'Production       ', 'CareerBuilder', 'Fully Meets', 5.0, 3, 0, '1/30/2013', 0, 15)
# (10167, 'Hitchcock, Alfred', 1, 1, 1, 1, 6, 3, 0, 70545, 0, 3, 'Area Sales Manager', 'NH', 3062, '9/14/1988', 'M ', 'Married', 'US Citizen', 'No', 'American Indian or Alaska Native', '8/18/2014', None, None, 'Active', 'Sales', 'Indeed', 'Fully Meets', 3.6, 5, 0, '1/30/2019', 0, 9)
# (10195, 'Homberger, Adrienne  J', 1, 1, 0, 5, 5, 3, 0, 63478, 1, 20, 'Production Technician II', 'MA', 2445, '2/16/1984', 'F', 'Married', 'Non-Citizen', 'No', 'White', '8/15/2011', '4/7/2012', 'relocation out of area', 'Voluntarily Terminated', 'Production       ', 'Indeed', 'Fully Meets', 3.03, 5, 0, '3/5/2012', 0, 16)
# (10112, 'Horton, Jayne', 0, 0, 0, 1, 3, 3, 0, 97999, 0, 8, 'Database Administrator', 'MA', 2493, '2/21/1984', 'F', 'Single', 'US Citizen', 'No', 'White', '3/30/2015', None, None, 'Active', 'IT/IS', 'Indeed', 'Fully Meets', 4.48, 5, 6, '1/3/2019', 0, 4)
# (10272, 'Houlihan, Debra', 1, 1, 0, 1, 6, 3, 0, 180000, 0, 11, 'Director of Sales', 'RI', 2908, '3/17/1966', 'F', 'Married', 'US Citizen', 'No', 'White', '5/5/2014', None, None, 'Active', 'Sales', 'LinkedIn', 'Fully Meets', 4.5, 4, 0, '1/21/2019', 0, 19)
# (10182, 'Howard, Estelle', 1, 1, 0, 1, 1, 3, 0, 49920, 1, 2, 'Administrative Assistant', 'MA', 2170, '9/16/1985', 'F', 'Married', 'US Citizen', 'No', 'Black or African American', '2/16/2015', '4/15/2015', 'no-call, no-show', 'Terminated for Cause', 'Admin Offices', 'Indeed', 'Fully Meets', 3.24, 3, 4, '4/15/2015', 0, 6)
# (10248, 'Hudson, Jane', 0, 0, 0, 1, 5, 3, 0, 55425, 0, 19, 'Production Technician I', 'MA', 2176, '6/10/1986', 'F', 'Single', 'US Citizen', 'No', 'White', '2/20/2012', None, None, 'Active', 'Production       ', 'LinkedIn', 'Fully Meets', 4.8, 4, 0, '1/7/2019', 0, 4)
# (10201, 'Hunts, Julissa', 0, 0, 0, 2, 5, 3, 0, 69340, 0, 20, 'Production Technician II', 'MA', 2021, '3/11/1984', 'F', 'Single', 'US Citizen', 'No', 'White', '6/6/2016', None, None, 'Active', 'Production       ', 'LinkedIn', 'Fully Meets', 3.0, 5, 0, '1/18/2019', 0, 4)
# (10214, 'Hutter, Rosalie', 0, 3, 0, 2, 5, 3, 0, 64995, 0, 20, 'Production Technician II', 'MA', 2351, '5/7/1992', 'F', 'Separated', 'US Citizen', 'No', 'White', '6/5/2015', None, None, 'Active', 'Production       ', 'Indeed', 'Fully Meets', 4.5, 3, 0, '2/14/2019', 0, 6)
# (10160, 'Huynh, Ming', 0, 2, 0, 5, 5, 3, 0, 68182, 1, 20, 'Production Technician II', 'MA', 1742, '9/22/1976', 'F', 'Divorced', 'US Citizen', 'No', 'White', '2/21/2011', '4/1/2013', 'unhappy', 'Voluntarily Terminated', 'Production       ', 'Google Search', 'Fully Meets', 3.72, 3, 0, '2/1/2013', 0, 18)
# (10289, 'Immediato, Walter', 1, 1, 1, 5, 5, 2, 0, 83082, 1, 18, 'Production Manager', 'MA', 2128, '11/15/1976', 'M ', 'Married', 'US Citizen', 'No', 'Asian', '2/21/2011', '9/24/2012', 'unhappy', 'Voluntarily Terminated', 'Production       ', 'Indeed', 'Needs Improvement', 2.34, 2, 0, '4/12/2012', 3, 4)
# (10139, 'Ivey, Rose ', 0, 0, 0, 1, 5, 3, 0, 51908, 0, 19, 'Production Technician I', 'MA', 1775, '1/28/1991', 'F', 'Single', 'US Citizen', 'No', 'White', '8/19/2013', None, None, 'Active', 'Production       ', 'Indeed', 'Fully Meets', 3.99, 3, 0, '1/14/2019', 0, 14)
# (10227, 'Jackson, Maryellen', 0, 0, 0, 1, 5, 3, 0, 61242, 0, 19, 'Production Technician I', 'MA', 2081, '9/11/1972', 'F', 'Single', 'US Citizen', 'No', 'Black or African American', '11/5/2012', None, None, 'Active', 'Production       ', 'LinkedIn', 'Fully Meets', 4.1, 3, 0, '1/17/2019', 0, 7)
# (10236, 'Jacobi, Hannah  ', 0, 2, 0, 1, 5, 3, 0, 45069, 0, 19, 'Production Technician I', 'MA', 1778, '3/22/1966', 'F', 'Divorced', 'US Citizen', 'No', 'White', '9/30/2013', None, None, 'Active', 'Production       ', 'Employee Referral', 'Fully Meets', 4.3, 5, 0, '2/22/2019', 0, 7)
# (10009, 'Jeannite, Tayana', 0, 2, 0, 1, 5, 4, 0, 60724, 0, 20, 'Production Technician II', 'MA', 1821, '11/6/1986', 'F', 'Divorced', 'US Citizen', 'No', 'American Indian or Alaska Native', '7/5/2011', None, None, 'Active', 'Production       ', 'LinkedIn', 'Exceeds', 4.6, 4, 0, '2/25/2019', 0, 11)
# (10060, 'Jhaveri, Sneha  ', 0, 3, 0, 1, 5, 3, 0, 60436, 0, 19, 'Production Technician I', 'MA', 2109, '4/13/1964', 'F', 'Separated', 'US Citizen', 'No', 'White', '1/6/2014', None, None, 'Active', 'Production       ', 'LinkedIn', 'Fully Meets', 5.0, 5, 0, '1/21/2019', 0, 9)
# (10034, 'Johnson, George', 1, 1, 1, 5, 5, 4, 0, 46837, 1, 19, 'Production Technician I', 'MA', 2445, '8/19/1959', 'M ', 'Married', 'US Citizen', 'No', 'White', '11/7/2011', '4/29/2018', 'more money', 'Voluntarily Terminated', 'Production       ', 'CareerBuilder', 'Exceeds', 4.7, 4, 0, '2/14/2018', 0, 9)
# (10156, 'Johnson, Noelle ', 1, 1, 0, 3, 3, 3, 0, 105700, 0, 8, 'Database Administrator', 'MA', 2301, '11/7/1986', 'F', 'Married', 'US Citizen', 'No', 'Asian', '1/5/2015', None, None, 'Active', 'IT/IS', 'Indeed', 'Fully Meets', 3.75, 3, 5, '2/11/2019', 0, 2)
# (10036, 'Johnston, Yen', 0, 0, 0, 1, 5, 4, 0, 63322, 0, 20, 'Production Technician II', 'MA', 2128, '9/8/1969', 'F', 'Single', 'US Citizen', 'No', 'White', '7/7/2014', None, None, 'Active', 'Production       ', 'LinkedIn', 'Exceeds', 4.3, 3, 0, '1/11/2019', 0, 1)
# (10138, 'Jung, Judy  ', 1, 1, 0, 5, 5, 3, 0, 61154, 1, 19, 'Production Technician I', 'MA', 2446, '4/17/1986', 'F', 'Married', 'US Citizen', 'No', 'Black or African American', '1/10/2011', '4/1/2016', 'unhappy', 'Voluntarily Terminated', 'Production       ', 'CareerBuilder', 'Fully Meets', 4.0, 4, 0, '2/3/2016', 0, 4)
# (10244, 'Kampew, Donysha', 0, 0, 0, 5, 6, 3, 0, 68999, 1, 21, 'Sales Manager', 'PA', 19444, '11/11/1989', 'F', 'Single', 'US Citizen', 'No', 'White', '11/7/2011', '4/24/2014', 'maternity leave - did not return', 'Voluntarily Terminated', 'Sales', 'Google Search', 'Fully Meets', 4.5, 5, 0, '3/30/2013', 0, 2)
# (10192, 'Keatts, Kramer ', 0, 0, 1, 1, 5, 3, 0, 50482, 0, 19, 'Production Technician I', 'MA', 1887, '1/19/1976', 'M ', 'Single', 'US Citizen', 'No', 'White', '9/30/2013', None, None, 'Active', 'Production       ', 'Indeed', 'Fully Meets', 3.07, 4, 0, '1/23/2019', 0, 10)
# (10231, 'Khemmich, Bartholemew', 0, 0, 1, 1, 6, 3, 0, 65310, 0, 3, 'Area Sales Manager', 'CO', 80820, '11/27/1979', 'M ', 'Single', 'US Citizen', 'No', 'White', '8/19/2013', None, None, 'Active', 'Sales', 'Indeed', 'Fully Meets', 4.3, 5, 0, '1/22/2019', 0, 13)
# (10089, 'King, Janet', 1, 1, 0, 1, 2, 3, 0, 250000, 0, 16, 'President & CEO', 'MA', 1902, '9/21/1954', 'F', 'Married', 'US Citizen', 'Yes', 'White', '7/2/2012', None, None, 'Active', 'Executive Office', 'Indeed', 'Fully Meets', 4.83, 3, 0, '1/17/2019', 0, 10)
# (10166, 'Kinsella, Kathleen  ', 1, 1, 0, 5, 5, 3, 0, 54005, 1, 19, 'Production Technician I', 'MA', 2170, '12/8/1973', 'F', 'Married', 'US Citizen', 'No', 'White', '9/26/2011', '6/4/2015', 'more money', 'Voluntarily Terminated', 'Production       ', 'Google Search', 'Fully Meets', 3.6, 5, 0, '3/1/2015', 0, 16)
# (10170, 'Kirill, Alexandra  ', 1, 1, 0, 5, 5, 3, 0, 45433, 1, 19, 'Production Technician I', 'MA', 2127, '10/8/1970', 'F', 'Married', 'US Citizen', 'No', 'White', '9/26/2011', '1/9/2014', 'more money', 'Voluntarily Terminated', 'Production       ', 'Google Search', 'Fully Meets', 3.49, 4, 0, '1/30/2013', 0, 6)
# (10208, 'Knapp, Bradley  J', 0, 0, 1, 1, 5, 3, 0, 46654, 0, 19, 'Production Technician I', 'MA', 1721, '11/10/1977', 'M ', 'Single', 'US Citizen', 'No', 'Black or African American', '2/17/2014', None, None, 'Active', 'Production       ', 'LinkedIn', 'Fully Meets', 3.1, 3, 0, '2/6/2019', 0, 3)
# (10176, 'Kretschmer, John', 1, 1, 1, 1, 5, 3, 0, 63973, 0, 19, 'Production Technician I', 'MA', 1801, '2/2/1980', 'M ', 'Married', 'US Citizen', 'No', 'Asian', '1/10/2011', None, None, 'Active', 'Production       ', 'Indeed', 'Fully Meets', 3.38, 3, 0, '1/21/2019', 0, 17)
# (10165, 'Kreuger, Freddy', 0, 0, 1, 1, 6, 3, 1, 71339, 0, 3, 'Area Sales Manager', 'NY', 10171, '2/24/1969', 'M ', 'Single', 'US Citizen', 'Yes', 'Black or African American', '3/7/2011', None, None, 'Active', 'Sales', 'Diversity Job Fair', 'Fully Meets', 3.65, 5, 0, '1/17/2019', 0, 20)
# (10113, 'Lajiri,  Jyoti', 1, 1, 1, 3, 3, 3, 0, 93206, 0, 28, 'Sr. Network Engineer', 'MA', 2169, '4/23/1986', 'M ', 'Married', 'US Citizen', 'No', 'White', '11/10/2014', None, None, 'Active', 'IT/IS', 'Employee Referral', 'Fully Meets', 4.46, 5, 6, '1/7/2019', 0, 7)
# (10092, 'Landa, Hans', 1, 1, 1, 4, 5, 3, 0, 82758, 1, 18, 'Production Manager', 'MA', 1890, '7/1/1972', 'M ', 'Married', 'US Citizen', 'No', 'White', '1/10/2011', '12/12/2015', 'attendance', 'Terminated for Cause', 'Production       ', 'Employee Referral', 'Fully Meets', 4.78, 4, 0, '2/15/2015', 0, 9)
# (10106, 'Langford, Lindsey', 0, 2, 0, 5, 5, 3, 0, 66074, 1, 20, 'Production Technician II', 'MA', 2090, '7/25/1979', 'F', 'Divorced', 'US Citizen', 'No', 'Asian', '1/7/2013', '3/31/2014', 'Another position', 'Voluntarily Terminated', 'Production       ', 'Indeed', 'Fully Meets', 4.52, 3, 0, '2/20/2014', 0, 20)
# (10052, 'Langton, Enrico', 1, 1, 1, 1, 5, 3, 0, 46120, 0, 19, 'Production Technician I', 'MA', 2048, '12/9/1986', 'M ', 'Married', 'US Citizen', 'No', 'White', '7/9/2012', None, None, 'Active', 'Production       ', 'LinkedIn', 'Fully Meets', 5.0, 5, 0, '2/4/2019', 0, 13)
# (10038, 'LaRotonda, William  ', 0, 2, 1, 1, 1, 3, 0, 64520, 0, 1, 'Accountant I', 'MA', 1460, '4/26/1984', 'M ', 'Divorced', 'US Citizen', 'No', 'Black or African American', '1/6/2014', None, None, 'Active', 'Admin Offices', 'Website', 'Fully Meets', 5.0, 4, 4, '1/17/2019', 0, 3)
# (10249, 'Latif, Mohammed', 1, 1, 1, 5, 5, 3, 0, 61962, 1, 20, 'Production Technician II', 'MA', 2126, '5/9/1984', 'M ', 'Married', 'US Citizen', 'No', 'White', '4/2/2012', '4/15/2013', 'more money', 'Voluntarily Terminated', 'Production       ', 'Google Search', 'Fully Meets', 4.9, 3, 0, '2/20/2013', 0, 20)
# (10232, 'Le, Binh', 0, 0, 0, 1, 3, 3, 0, 81584, 0, 22, 'Senior BI Developer', 'MA', 1886, '6/14/1987', 'F', 'Single', 'US Citizen', 'No', 'Asian', '10/2/2016', None, None, 'Active', 'IT/IS', 'Indeed', 'Fully Meets', 4.1, 5, 7, '1/8/2019', 0, 2)
# (10087, 'Leach, Dallas', 0, 0, 0, 5, 5, 3, 0, 63676, 1, 19, 'Production Technician I', 'MA', 1810, '1/17/1979', 'F', 'Single', 'US Citizen', 'No', 'Asian', '9/26/2011', '8/19/2018', 'return to school', 'Voluntarily Terminated', 'Production       ', 'CareerBuilder', 'Fully Meets', 4.88, 3, 0, '7/2/2017', 0, 17)
# (10134, 'LeBlanc, Brandon  R', 1, 1, 1, 1, 1, 3, 0, 93046, 0, 23, 'Shared Services Manager', 'MA', 1460, '6/10/1984', 'M ', 'Married', 'US Citizen', 'No', 'White', '1/5/2016', None, None, 'Active', 'Admin Offices', 'CareerBuilder', 'Fully Meets', 4.1, 4, 0, '1/28/2019', 0, 20)
# (10251, 'Lecter, Hannibal', 1, 1, 1, 1, 5, 3, 0, 64738, 0, 19, 'Production Technician I', 'MA', 1776, '9/2/1982', 'M ', 'Married', 'US Citizen', 'No', 'Asian', '5/14/2012', None, None, 'Active', 'Production       ', 'Google Search', 'Fully Meets', 4.1, 3, 0, '2/22/2019', 0, 10)
# (10103, 'Leruth, Giovanni', 0, 3, 1, 1, 6, 3, 0, 70468, 0, 3, 'Area Sales Manager', 'UT', 84111, '12/27/1988', 'M ', 'Separated', 'US Citizen', 'No', 'Black or African American', '4/30/2012', None, None, 'Active', 'Sales', 'Website', 'Fully Meets', 4.53, 3, 0, '1/29/2019', 0, 16)
# (10017, 'Liebig, Ketsia', 1, 1, 0, 1, 5, 4, 0, 77915, 0, 18, 'Production Manager', 'MA', 2110, '10/26/1981', 'F', 'Married', 'US Citizen', 'No', 'White', '9/30/2013', None, None, 'Active', 'Production       ', 'Website', 'Exceeds', 4.1, 3, 0, '1/21/2019', 0, 11)
# ...
# (10095, 'Sloan, Constance', 0, 0, 0, 5, 5, 3, 0, 63878, 1, 20, 'Production Technician II', 'MA', 1851, '11/25/1987', 'F', 'Single', 'US Citizen', 'No', 'White', '10/26/2009', '4/8/2015', 'maternity leave - did not return', 'Voluntarily Terminated', 'Production       ', 'CareerBuilder', 'Fully Meets', 4.68, 4, 0, '4/2/2015', 0, 20)
# (10027, 'Smith, Joe', 0, 0, 1, 1, 5, 4, 0, 60656, 0, 20, 'Production Technician II', 'MA', 2045, '10/30/1963', 'M ', 'Single', 'US Citizen', 'No', 'White', '9/29/2014', None, None, 'Active', 'Production       ', 'Indeed', 'Exceeds', 4.3, 3, 0, '1/28/2019', 0, 4)
# (10291, 'Smith, John', 0, 2, 1, 1, 6, 2, 1, 72992, 0, 21, 'Sales Manager', 'MA', 1886, '8/16/1984', 'M ', 'Divorced', 'US Citizen', 'No', 'Black or African American', '5/18/2014', None, None, 'Active', 'Sales', 'Diversity Job Fair', 'Needs Improvement', 2.4, 4, 0, '1/16/2019', 2, 16)
# (10153, 'Smith, Leigh Ann', 1, 1, 0, 5, 1, 3, 1, 55000, 1, 2, 'Administrative Assistant', 'MA', 1844, '6/14/1987', 'F', 'Married', 'US Citizen', 'No', 'Black or African American', '9/26/2011', '9/25/2013', 'career change', 'Voluntarily Terminated', 'Admin Offices', 'Diversity Job Fair', 'Fully Meets', 3.8, 4, 4, '8/15/2013', 0, 17)
# (10157, 'Smith, Sade', 0, 0, 0, 1, 5, 3, 0, 58939, 0, 19, 'Production Technician I', 'MA', 2130, '2/2/1965', 'F', 'Single', 'US Citizen', 'No', 'White', '11/11/2013', None, None, 'Active', 'Production       ', 'Employee Referral', 'Fully Meets', 3.73, 3, 0, '1/24/2019', 0, 16)
# (10119, 'Soto, Julia ', 1, 1, 0, 1, 3, 3, 0, 66593, 0, 14, 'IT Support', 'MA', 2360, '3/12/1973', 'F', 'Married', 'US Citizen', 'No', 'Black or African American', '6/10/2011', None, None, 'Active', 'IT/IS', 'LinkedIn', 'Fully Meets', 4.3, 3, 5, '2/8/2019', 0, 19)
# (10180, 'Soze, Keyser', 1, 1, 1, 2, 3, 3, 0, 87565, 0, 28, 'Sr. Network Engineer', 'MA', 1545, '2/9/1983', 'M ', 'Married', 'US Citizen', 'No', 'Asian', '6/30/2016', None, None, 'Active', 'IT/IS', 'LinkedIn', 'Fully Meets', 3.27, 4, 5, '1/14/2019', 0, 13)
# (10302, 'Sparks, Taylor  ', 1, 1, 0, 1, 5, 1, 0, 64021, 0, 19, 'Production Technician I', 'MA', 2093, '7/20/1968', 'F', 'Married', 'US Citizen', 'No', 'White', '2/20/2012', None, None, 'Active', 'Production       ', 'Indeed', 'PIP', 2.4, 2, 1, '2/25/2019', 6, 20)
# (10090, 'Spirea, Kelley', 1, 1, 0, 1, 5, 3, 0, 65714, 0, 18, 'Production Manager', 'MA', 2451, '9/30/1975', 'F', 'Married', 'US Citizen', 'No', 'White', '10/2/2012', None, None, 'Active', 'Production       ', 'LinkedIn', 'Fully Meets', 4.83, 5, 0, '2/14/2019', 0, 15)
# (10030, 'Squatrito, Kristen', 0, 2, 0, 5, 5, 4, 0, 62425, 1, 19, 'Production Technician I', 'MA', 2359, '3/26/1973', 'F', 'Divorced', 'US Citizen', 'No', 'White', '5/13/2013', '6/29/2015', 'unhappy', 'Voluntarily Terminated', 'Production       ', 'LinkedIn', 'Exceeds', 4.1, 4, 0, '3/2/2015', 0, 16)
# (10278, 'Stanford,Barbara  M', 0, 2, 0, 1, 5, 3, 0, 47961, 0, 19, 'Production Technician I', 'MA', 2050, '8/25/1982', 'F', 'Divorced', 'US Citizen', 'No', 'Two or more races', '1/10/2011', None, None, 'Active', 'Production       ', 'Google Search', 'Fully Meets', 4.1, 4, 0, '2/7/2019', 0, 9)
# (10307, 'Stansfield, Norman', 1, 1, 1, 1, 6, 1, 0, 58273, 0, 3, 'Area Sales Manager', 'NV', 89139, '5/9/1974', 'M ', 'Married', 'US Citizen', 'No', 'White', '5/12/2014', None, None, 'Active', 'Sales', 'Website', 'PIP', 1.81, 2, 0, '1/17/2019', 3, 5)
# (10147, 'Steans, Tyrone  ', 0, 0, 1, 1, 1, 3, 0, 63003, 0, 1, 'Accountant I', 'MA', 2703, '9/1/1986', 'M ', 'Single', 'US Citizen', 'No', 'White', '9/29/2014', None, None, 'Active', 'Admin Offices', 'Indeed', 'Fully Meets', 3.9, 5, 5, '1/18/2019', 0, 9)
# (10266, 'Stoica, Rick', 1, 1, 1, 1, 5, 3, 0, 61355, 0, 19, 'Production Technician I', 'MA', 2301, '3/14/1985', 'M ', 'Married', 'US Citizen', 'No', 'Asian', '2/17/2014', None, None, 'Active', 'Production       ', 'LinkedIn', 'Fully Meets', 4.7, 3, 0, '1/11/2019', 0, 4)
# (10241, 'Strong, Caitrin', 1, 1, 0, 1, 6, 3, 0, 60120, 0, 3, 'Area Sales Manager', 'MT', 59102, '5/12/1989', 'F', 'Married', 'US Citizen', 'No', 'Black or African American', '9/27/2010', None, None, 'Active', 'Sales', 'Indeed', 'Fully Meets', 4.1, 4, 0, '1/31/2019', 0, 18)
# (10158, 'Sullivan, Kissy ', 1, 1, 0, 1, 5, 3, 0, 63682, 0, 18, 'Production Manager', 'MA', 1776, '3/28/1978', 'F', 'Married', 'US Citizen', 'No', 'Black or African American', '1/8/2009', None, None, 'Active', 'Production       ', 'Indeed', 'Fully Meets', 3.73, 4, 0, '1/24/2019', 0, 12)
# (10117, 'Sullivan, Timothy', 1, 1, 1, 1, 5, 3, 0, 63025, 0, 19, 'Production Technician I', 'MA', 2747, '10/7/1982', 'M ', 'Married', 'US Citizen', 'Yes', 'White', '1/5/2015', None, None, 'Active', 'Production       ', 'Google Search', 'Fully Meets', 4.36, 5, 0, '1/24/2019', 0, 10)
# (10209, 'Sutwell, Barbara', 0, 0, 0, 1, 5, 3, 0, 59238, 0, 19, 'Production Technician I', 'MA', 2718, '8/15/1968', 'F', 'Single', 'Eligible NonCitizen', 'No', 'Asian', '5/14/2012', None, None, 'Active', 'Production       ', 'Indeed', 'Fully Meets', 3.4, 5, 0, '1/31/2019', 0, 13)
# (10024, 'Szabo, Andrew', 0, 0, 1, 1, 4, 4, 0, 92989, 0, 24, 'Software Engineer', 'MA', 2140, '5/6/1983', 'M ', 'Single', 'US Citizen', 'No', 'White', '7/7/2014', None, None, 'Active', 'Software Engineering', 'LinkedIn', 'Exceeds', 4.5, 5, 5, '2/18/2019', 0, 1)
# (10173, 'Tannen, Biff', 1, 1, 1, 1, 3, 3, 0, 90100, 0, 4, 'BI Developer', 'MA', 2134, '10/24/1987', 'M ', 'Married', 'US Citizen', 'No', 'White', '4/20/2017', None, None, 'Active', 'IT/IS', 'Indeed', 'Fully Meets', 3.4, 3, 6, '1/2/2019', 0, 14)
# (10221, 'Tavares, Desiree  ', 1, 1, 0, 5, 5, 3, 1, 60754, 1, 19, 'Production Technician I', 'MA', 1801, '4/3/1975', 'F', 'Married', 'Non-Citizen', 'No', 'Black or African American', '4/27/2009', '4/1/2013', 'Another position', 'Voluntarily Terminated', 'Production       ', 'Diversity Job Fair', 'Fully Meets', 4.5, 5, 0, '2/15/2012', 0, 11)
# (10146, 'Tejeda, Lenora ', 1, 1, 0, 5, 5, 3, 0, 72202, 1, 20, 'Production Technician II', 'MA', 2129, '5/24/1953', 'F', 'Married', 'US Citizen', 'No', 'White', '5/16/2011', '7/8/2017', 'Another position', 'Voluntarily Terminated', 'Production       ', 'Google Search', 'Fully Meets', 3.93, 3, 0, '4/18/2017', 0, 3)
# (10161, 'Terry, Sharlene ', 0, 0, 0, 1, 6, 3, 0, 58370, 0, 3, 'Area Sales Manager', 'OR', 97756, '5/7/1965', 'F', 'Single', 'US Citizen', 'No', 'Black or African American', '9/29/2014', None, None, 'Active', 'Sales', 'Indeed', 'Fully Meets', 3.69, 3, 0, '1/28/2019', 0, 18)
# (10141, 'Theamstern, Sophia', 0, 0, 0, 5, 5, 3, 0, 48413, 1, 19, 'Production Technician I', 'MA', 2066, '5/9/1965', 'F', 'Single', 'US Citizen', 'No', 'White', '7/5/2011', '9/5/2016', 'return to school', 'Voluntarily Terminated', 'Production       ', 'Indeed', 'Fully Meets', 3.98, 4, 0, '3/2/2016', 0, 1)
# (10268, 'Thibaud, Kenneth', 0, 4, 1, 5, 5, 3, 0, 67176, 1, 20, 'Production Technician II', 'MA', 2472, '9/16/1975', 'M ', 'Widowed', 'US Citizen', 'No', 'White', '6/25/2007', '8/30/2010', 'military', 'Voluntarily Terminated', 'Production       ', 'Other', 'Fully Meets', 4.1, 4, 0, '7/14/2010', 0, 15)
# (10123, 'Tippett, Jeanette', 0, 2, 0, 1, 5, 3, 0, 56339, 0, 19, 'Production Technician I', 'MA', 2093, '6/5/1967', 'F', 'Divorced', 'US Citizen', 'No', 'Black or African American', '2/18/2013', None, None, 'Active', 'Production       ', 'Indeed', 'Fully Meets', 4.21, 5, 0, '1/14/2019', 0, 4)
# (10013, 'Torrence, Jack', 0, 3, 1, 1, 6, 4, 0, 64397, 0, 3, 'Area Sales Manager', 'ND', 58782, '1/15/1968', 'M ', 'Separated', 'US Citizen', 'No', 'White', '1/9/2006', None, None, 'Active', 'Sales', 'Indeed', 'Exceeds', 4.1, 3, 0, '1/4/2019', 0, 6)
# (10287, 'Trang, Mei', 0, 0, 0, 1, 5, 2, 0, 63025, 0, 19, 'Production Technician I', 'MA', 2021, '5/16/1983', 'F', 'Single', 'US Citizen', 'No', 'White', '2/17/2014', None, None, 'Active', 'Production       ', 'LinkedIn', 'Needs Improvement', 2.44, 5, 0, '2/11/2019', 4, 18)
# (10044, 'Tredinnick, Neville ', 1, 1, 1, 5, 3, 3, 0, 75281, 1, 15, 'Network Engineer', 'MA', 1420, '5/5/1988', 'M ', 'Married', 'US Citizen', 'No', 'White', '1/5/2015', '2/12/2016', 'medical issues', 'Voluntarily Terminated', 'IT/IS', 'CareerBuilder', 'Fully Meets', 5.0, 3, 5, '4/15/2015', 0, 11)
# (10102, 'True, Edward', 0, 0, 1, 5, 4, 3, 1, 100416, 1, 24, 'Software Engineer', 'MA', 2451, '6/14/1983', 'M ', 'Single', 'Non-Citizen', 'No', 'Black or African American', '2/18/2013', '4/15/2018', 'medical issues', 'Voluntarily Terminated', 'Software Engineering', 'Diversity Job Fair', 'Fully Meets', 4.6, 3, 4, '2/12/2017', 0, 9)
# (10270, 'Trzeciak, Cybil', 0, 0, 0, 5, 5, 3, 0, 74813, 1, 20, 'Production Technician II', 'MA', 1778, '3/15/1985', 'F', 'Single', 'US Citizen', 'No', 'White', '1/10/2011', '7/2/2014', 'unhappy', 'Voluntarily Terminated', 'Production       ', 'LinkedIn', 'Fully Meets', 4.4, 3, 0, '1/5/2014', 0, 5)
# (10045, 'Turpin, Jumil', 1, 1, 1, 1, 3, 3, 0, 76029, 0, 15, 'Network Engineer', 'MA', 2343, '3/31/1969', 'M ', 'Married', 'Eligible NonCitizen', 'No', 'White', '3/30/2015', None, None, 'Active', 'IT/IS', 'Employee Referral', 'Fully Meets', 5.0, 4, 7, '1/14/2019', 0, 8)
# (10205, 'Valentin,Jackie', 1, 1, 0, 1, 6, 3, 0, 57859, 0, 3, 'Area Sales Manager', 'AZ', 85006, '5/23/1991', 'F', 'Married', 'US Citizen', 'No', 'Two or more races', '7/5/2011', None, None, 'Active', 'Sales', 'Indeed', 'Fully Meets', 2.81, 3, 0, '1/17/2019', 0, 16)
# (10014, 'Veera, Abdellah ', 0, 2, 1, 5, 5, 4, 0, 58523, 1, 19, 'Production Technician I', 'MA', 2171, '1/31/1987', 'M ', 'Divorced', 'US Citizen', 'No', 'White', '8/13/2012', '2/5/2016', 'maternity leave - did not return', 'Voluntarily Terminated', 'Production       ', 'LinkedIn', 'Exceeds', 4.5, 5, 0, '2/1/2016', 0, 15)
# (10144, 'Vega, Vincent', 0, 2, 1, 1, 5, 3, 0, 88976, 0, 17, 'Production Manager', 'MA', 2169, '10/10/1968', 'M ', 'Divorced', 'US Citizen', 'No', 'White', '8/1/2011', None, None, 'Active', 'Production       ', 'Employee Referral', 'Fully Meets', 3.93, 3, 0, '2/27/2019', 0, 19)
# (10253, 'Villanueva, Noah', 0, 0, 1, 1, 6, 3, 0, 55875, 0, 3, 'Area Sales Manager', 'ME', 4063, '7/11/1989', 'M ', 'Single', 'US Citizen', 'No', 'Asian', '3/5/2012', None, None, 'Active', 'Sales', 'Website', 'Fully Meets', 4.5, 4, 0, '1/18/2019', 0, 11)
# (10118, 'Voldemort, Lord', 1, 1, 1, 4, 3, 3, 0, 113999, 1, 8, 'Database Administrator', 'MA', 1960, '8/7/1986', 'M ', 'Married', 'US Citizen', 'No', 'Black or African American', '2/16/2015', '2/22/2017', 'no-call, no-show', 'Terminated for Cause', 'IT/IS', 'Employee Referral', 'Fully Meets', 4.33, 3, 7, '2/15/2017', 0, 9)
# (10022, 'Volk, Colleen', 1, 1, 0, 4, 5, 4, 0, 49773, 1, 19, 'Production Technician I', 'MA', 2747, '6/3/1986', 'F', 'Married', 'US Citizen', 'No', 'White', '9/26/2011', '2/8/2016', 'gross misconduct', 'Terminated for Cause', 'Production       ', 'Google Search', 'Exceeds', 4.3, 5, 0, '2/1/2015', 0, 18)
# (10183, 'Von Massenbach, Anna', 0, 0, 0, 2, 5, 3, 0, 62068, 0, 19, 'Production Technician I', 'MA', 2124, '4/6/1985', 'F', 'Single', 'US Citizen', 'No', 'White', '7/5/2015', None, None, 'Active', 'Production       ', 'LinkedIn', 'Fully Meets', 3.21, 3, 0, '1/29/2019', 0, 7)
# (10190, 'Walker, Roger', 0, 0, 1, 1, 5, 3, 0, 66541, 0, 20, 'Production Technician II', 'MA', 2459, '2/10/1976', 'M ', 'Single', 'US Citizen', 'No', 'Black or African American', '8/18/2014', None, None, 'Active', 'Production       ', 'Employee Referral', 'Fully Meets', 3.11, 5, 0, '2/12/2019', 0, 4)
# (10274, 'Wallace, Courtney  E', 1, 1, 0, 5, 5, 3, 1, 80512, 1, 18, 'Production Manager', 'MA', 2478, '11/14/1955', 'F', 'Married', 'US Citizen', 'No', 'Black or African American', '9/26/2011', '1/2/2012', 'Another position', 'Voluntarily Terminated', 'Production       ', 'Diversity Job Fair', 'Fully Meets', 4.5, 3, 0, '1/2/2012', 0, 5)
# (10293, 'Wallace, Theresa', 0, 0, 0, 5, 5, 2, 0, 50274, 1, 19, 'Production Technician I', 'MA', 1887, '8/2/1980', 'F', 'Single', 'US Citizen', 'No', 'White', '8/13/2012', '9/1/2015', 'career change', 'Voluntarily Terminated', 'Production       ', 'CareerBuilder', 'Needs Improvement', 2.5, 3, 0, '9/5/2014', 6, 13)
# (10172, 'Wang, Charlie', 0, 0, 1, 1, 3, 3, 0, 84903, 0, 22, 'Senior BI Developer', 'MA', 1887, '7/8/1981', 'M ', 'Single', 'US Citizen', 'No', 'Asian', '2/15/2017', None, None, 'Active', 'IT/IS', 'Indeed', 'Fully Meets', 3.42, 4, 7, '1/4/2019', 0, 17)
# (10127, 'Warfield, Sarah', 0, 4, 0, 1, 3, 3, 0, 107226, 0, 28, 'Sr. Network Engineer', 'MA', 2453, '5/2/1978', 'F', 'Widowed', 'US Citizen', 'No', 'Asian', '3/30/2015', None, None, 'Active', 'IT/IS', 'Employee Referral', 'Fully Meets', 4.2, 4, 8, '2/5/2019', 0, 7)
# (10072, 'Whittier, Scott', 0, 0, 1, 5, 5, 3, 0, 58371, 1, 19, 'Production Technician I', 'MA', 2030, '5/24/1987', 'M ', 'Single', 'US Citizen', 'Yes', 'White', '1/10/2011', '5/15/2014', 'hours', 'Voluntarily Terminated', 'Production       ', 'LinkedIn', 'Fully Meets', 5.0, 5, 0, '5/15/2014', 0, 11)
# (10048, 'Wilber, Barry', 1, 1, 1, 5, 5, 3, 0, 55140, 1, 19, 'Production Technician I', 'MA', 2324, '9/9/1965', 'M ', 'Married', 'Eligible NonCitizen', 'No', 'White', '5/16/2011', '9/7/2015', 'unhappy', 'Voluntarily Terminated', 'Production       ', 'Website', 'Fully Meets', 5.0, 3, 0, '2/15/2015', 0, 7)
# (10204, 'Wilkes, Annie', 0, 2, 0, 5, 5, 3, 0, 58062, 1, 19, 'Production Technician I', 'MA', 1876, '7/30/1983', 'F', 'Divorced', 'US Citizen', 'No', 'White', '1/10/2011', '5/14/2012', 'Another position', 'Voluntarily Terminated', 'Production       ', 'Google Search', 'Fully Meets', 3.6, 5, 0, '2/6/2011', 0, 9)
# (10264, 'Williams, Jacquelyn  ', 0, 0, 0, 5, 5, 3, 1, 59728, 1, 19, 'Production Technician I', 'MA', 2109, '10/2/1969', 'F', 'Single', 'US Citizen', 'Yes', 'Black or African American', '1/9/2012', '6/27/2015', 'relocation out of area', 'Voluntarily Terminated', 'Production       ', 'Diversity Job Fair', 'Fully Meets', 4.3, 4, 0, '6/2/2014', 0, 16)
# (10033, 'Winthrop, Jordan  ', 0, 0, 1, 5, 5, 4, 0, 70507, 1, 20, 'Production Technician II', 'MA', 2045, '11/7/1958', 'M ', 'Single', 'US Citizen', 'No', 'White', '1/7/2013', '2/21/2016', 'retiring', 'Voluntarily Terminated', 'Production       ', 'LinkedIn', 'Exceeds', 5.0, 3, 0, '1/19/2016', 0, 7)
# (10174, 'Wolk, Hang  T', 0, 0, 0, 1, 5, 3, 0, 60446, 0, 20, 'Production Technician II', 'MA', 2302, '4/20/1985', 'F', 'Single', 'US Citizen', 'No', 'White', '9/29/2014', None, None, 'Active', 'Production       ', 'LinkedIn', 'Fully Meets', 3.4, 4, 0, '2/21/2019', 0, 14)
# (10135, 'Woodson, Jason', 0, 0, 1, 1, 5, 3, 0, 65893, 0, 20, 'Production Technician II', 'MA', 1810, '5/11/1985', 'M ', 'Single', 'US Citizen', 'No', 'White', '7/7/2014', None, None, 'Active', 'Production       ', 'LinkedIn', 'Fully Meets', 4.07, 4, 0, '2/28/2019', 0, 13)
# (10301, 'Ybarra, Catherine ', 0, 0, 0, 5, 5, 1, 0, 48513, 1, 19, 'Production Technician I', 'MA', 2458, '5/4/1982', 'F', 'Single', 'US Citizen', 'No', 'Asian', '9/2/2008', '9/29/2015', 'Another position', 'Voluntarily Terminated', 'Production       ', 'Google Search', 'PIP', 3.2, 2, 0, '9/2/2015', 5, 4)
# (10010, 'Zamora, Jennifer', 0, 0, 0, 1, 3, 4, 0, 220450, 0, 6, 'CIO', 'MA', 2067, '8/30/1979', 'F', 'Single', 'US Citizen', 'No', 'White', '4/10/2010', None, None, 'Active', 'IT/IS', 'Employee Referral', 'Exceeds', 4.6, 5, 6, '2/21/2019', 0, 16)
# (10043, 'Zhou, Julia', 0, 0, 0, 1, 3, 3, 0, 89292, 0, 9, 'Data Analyst', 'MA', 2148, '2/24/1979', 'F', 'Single', 'US Citizen', 'No', 'White', '3/30/2015', None, None, 'Active', 'IT/IS', 'Employee Referral', 'Fully Meets', 5.0, 3, 5, '2/1/2019', 0, 11)
# (10271, 'Zima, Colleen', 0, 4, 0, 1, 5, 3, 0, 45046, 0, 19, 'Production Technician I', 'MA', 1730, '8/17/1978', 'F', 'Widowed', 'US Citizen', 'No', 'Asian', '9/29/2014', None, None, 'Active', 'Production       ', 'LinkedIn', 'Fully Meets', 4.5, 5, 0, '1/30/2019', 0, 2)

# %%
con.close()
